# %% [markdown]
# # Cifar10 Classification

# %% [markdown]
# Until now, we have implemented several pieces of a deep learning pipeline and even trained a two-layer neural network, but all the hyperparameters were already set to some values yielding resonable results. In real-life problems, however, much of the work in a deep learning project will be geared towards finding the best hyperparameters for a certain problem. In this notebook we will explore some good practices for network debugging and hyperparameters search, as well as extending our previously binary classification neural network to a multi-class one.
#
# Let's go!

# %%
# Some lengthy setup.
import matplotlib.pyplot as plt
import numpy as np
import os

from exercise_code.networks.layer import (
    Sigmoid, 
    Relu, 
    LeakyRelu, 
    Tanh,
)
from exercise_code.data import (
    DataLoader,
    ImageFolderDataset,
    RescaleTransform,
    NormalizeTransform,
    FlattenTransform,
    ComposeTransform,
)
from exercise_code.data.image_folder_dataset import RandomHorizontalFlip
from exercise_code.networks import (
    ClassificationNet,
    BCE,
    CrossEntropyFromLogits
)

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %% [markdown]
# # 1. Quick recap (and some new things)

# %% [markdown]
# Until now, in the previous exercises, we focused on building and understanding all the necessary modules for training a simple model. We followed the Pytorch implementations closely, as this is the framework we will use later and we want you to have a smoother transition to its APIs.
#
# In the figure below you can see the main components in Pytorch. Before starting the actual exercise, we begin with a quick recap of **our implementation** of these components.
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>Everything is already implemented for this part, but we <b>strongly</b> encourage you to check out the respective source files in order to have a better understanding. </p>
# </div>

# %% [markdown]
# <img src="https://cdn-images-1.medium.com/max/800/1*uZrS4KjAuSJQIJPgOiaJUg.png" style="width: 500px;">

# %% [markdown]
# ## 1.1 Dataset and Dataloader

# %% [markdown]
# Data preparation represents an important part of deep learning projects. The data comes from different sources and in different formats and is prepared differently from application to application. One part, however, is clear: because entire datasets are usually too large for us to handle at once, we train our models on smaller batches of data.
#
# The goal of the ```Dataset``` class is to encapsulate all the 'dirty' data processing: loading and cleaning the data, storing features (or names of files where features can be found) and labels, as well as providing the means for accessing individual (transformed) items of the data using the ```__getitem__()``` function and an index. You already implemented an ```ImageFolderDataset``` (in ```exercise_code/data/image_folder_dataset.py```) class in Exercise 3. We we will reuse this class here.
#
# For processing the data, you implemented several transforms in Exercise 3 (```RescaleTransform```, ```NormalizeTransform```, ```ComposeTransform```). In this exercise we are working with images, which are multidimensional arrays, but we are using simple feedforward neural network which takes a one dimensional array as an input, so it is necessary to reshape the images before feeding them into the model.
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>Please check the implementation of the reshape operation in the <code>FlattenTransform</code> class, which can be found in <code>../exercise_06/exercise_code/data/image_folder_dataset.py</code>. </p>
# </div>

# %%
download_url = "https://i2dl.vc.in.tum.de/static/data/cifar10.zip"
i2dl_exercises_path = os.path.dirname(os.path.abspath(os.getcwd()))
cifar_root = os.path.join(i2dl_exercises_path, "datasets", "cifar10")

# Use the Cifar10 mean and standard deviation computed in Exercise 3.
cifar_mean = np.array([0.49191375, 0.48235852, 0.44673872])
cifar_std  = np.array([0.24706447, 0.24346213, 0.26147554])

# Define all the transforms we will apply on the images when 
# retrieving them.
rescale_transform = RescaleTransform()
normalize_transform = NormalizeTransform(
    mean=cifar_mean,
    std=cifar_std
)
flatten_transform = FlattenTransform()
compose_transform = ComposeTransform([rescale_transform, 
                                      normalize_transform,
                                      flatten_transform])

# Create a train, validation and test dataset.
datasets = {}
for mode in ['train', 'val', 'test']:
    crt_dataset = ImageFolderDataset(
        mode=mode,
        root=cifar_root, 
        download_url=download_url,
        transform=compose_transform,
        split={'train': 0.6, 'val': 0.2, 'test': 0.2}
    )
    datasets[mode] = crt_dataset

# %% [markdown]
# Then, based on this ```Dataset``` object, we can construct a ```Dataloader``` object which samples a random mini-batch of data at once.

# %%
# Create a dataloader for each split.
dataloaders = {}
for mode in ['train', 'val', 'test']:
    crt_dataloader = DataLoader(
        dataset=datasets[mode],
        batch_size=256,
        shuffle=True,
        drop_last=True,
    )
    dataloaders[mode] = crt_dataloader

# %% [markdown]
# Because the ```Dataloader``` has the ```__iter__()``` method, we can simply iterate through the batches it produces, like this:
#
# ```python
# for batch in dataloader['train']:
#     do_something(batch)
# ```

# %% [markdown]
# ## 1.2 Data Augmentation
#
# After the above preprocessing steps, our data is in a good shape and ready to be fed into our network. As explained in the chapter above, we used the transformation functions `RescaleTransform`, `NormalizeTransform` and `FlattenTransform` to achieve this shape. These are the general steps that you need to perform on the data before we can even start the training. Of course, all these steps have to be applied to all three splits of our dataset (train, val and test split). So in other words, preprocessing involves preparing the data before they are used in training and inference.
#
# Besides these basic transformations, there are many other transformation methods that you can apply to the images. For example, you can <b>flip the images horizontally</b> or <b>blur the image</b> and use these new images to enlarge your dataset. This idea is called Data Augmentation and it involves methods that alter the training images to generate a synthetic dataset that is larger than your original dataset and will hopefully improve the performance of your model. The purpose here is different than in the data preprocessing steps and there is one big difference between data augmentation and data preprocessing: The transformation methods to enlarge your dataset should only be applied to the training data. The validation and test data are not affected by these methods.
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>The choice of transformation methods to use for data augmentation can be seen as a hyperparameter of your model and you can try to include these to enlarge your training data and obtain better results for your model. In <code>exercise_code/data/image_folder_dataset.py</code> we implemented the function <code>RandomHorizontalFlip</code> for you, which is randomly flipping an image. Check out the implementation.</p>
#     <p> Later, we will apply some hyperparameter tuning and in order to improve your model's accuracy, you could try to include some data augmentation methods. Fell free to play around and maybe also implement some other methods as for example Gaussian Blur or Rotation. </p>
# </div>
#
# Let us quickly check out the `RandomHorizontalFlip` method with an image of the Cifar10 dataset in the following cell.

# %%
#Load the data in a dataset without any transformation 
dataset = ImageFolderDataset(
        mode=mode,
        root=cifar_root, 
        download_url=download_url,
        split={'train': 0.6, 'val': 0.2, 'test': 0.2},
    )

#Retrieve an image from the dataset and flip it
image = dataset[1]['image']
transform = RandomHorizontalFlip(1)
image_flipped = transform(image)

#Show the two images
plt.figure(figsize = (2,2))
plt.subplot(1, 2, 1)
plt.imshow(image.astype('uint8'))
plt.axis('off')
plt.subplot(1, 2, 2)
plt.imshow(image_flipped.astype('uint8'))
plt.axis('off')
plt.title("Left: Original Image, Right: Flipped image")
plt.show()

# %% [markdown]
# ## 1.3 Layers
#
# Now, that the data is prepared, we can discuss the model in which we are feeding the data. In our case the model will be a neural network.
#
# In Exercise 5, you implemented a simple 2-layer neural network that had a hidden size as a parameter:
#
# $$
# {\hat{y}} = \sigma(\sigma({x W_1} + {b_1}) {W_2} + {b_2})
# $$
#
# where $ \sigma({x}) $ was the sigmoid function, $ {x} $ was the input, $ {W_1}, {W_2} $ the weight matrices and $ {b_1}, {b_2}$ the biases for the two layers.
#
# This is how we used this network:

# %%
input_size = datasets['train'][0]['image'].shape[0]
model = ClassificationNet(input_size=input_size, 
                          hidden_size=512)

# %% [markdown]
# Note that we updated the ```ClassificationNet``` from the previous exercise, so that now you can customize more: the number of outputs, the choice of activation function, the hidden size etc. We encourage you to check out the implementation in ```exercise_code/networks/classification_net.py```

# %%
num_layer = 2
reg = 0.1

model = ClassificationNet(activation=Sigmoid(), 
                          num_layer=num_layer, 
                          reg=reg,
                          num_classes=10)

# %% [markdown]
# Then, the forward and backward passes through the model were simply:
#
# ```python
#
# # X is a batch of training features
# # X.shape = (batch_size, features_size)
# y_out = model.forward(X)
#
# # dout is the gradient of the loss function w.r.t the output of the network.
# # dout.shape = (batch_size, )
# model.backward(dout)
# ```

# %% [markdown]
# Just as the learning rate or the number of iterations we want to train for, the number of hidden layers and the number of units in each hidden layer are also hyperparameters. In this notebook you will play with networks of different sizes and will see the impact that the network capacity has.
#
# Before we move on to the loss functions, we want to have a look at the activation functions. The choice of an activation function can have a huge impact on the performance of the network that you are designing. So far, you have implemented the `Sigmoid` and the `Relu` activation function in Exercise 5.
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>Take a look at the <code>Sigmoid</code> and the <code>Relu</code> class in <code>exercise_code/networks/layer.py</code> and the implementation of the respective forward and backward pass. Make sure to understand why we use <b>element-wise product</b> instead of dot product in the backward pass of the <code>Sigmoid</code> class to compute the gradient $dx$. That will be helpful for your later implementation of other activation functions.</p>
#     <p> <b>Note:</b> The <code>cache</code> variable is used to store information from the forward pass and then pass this information in the backward pass to make use of it there. The implementation of both classes show that this variable can be used differently - depending on what information is needed in the backward pass. </p>
# </div>
#
# Now, we want to have a look at two other, very common activation functions that you have already met in the lecture: Leaky ReLU activation function and Tanh activation function.
#
# **Leaky Relus** are one attempt to fix the “dying ReLU” problem. Instead of the function being zero when $x<0$, a leaky ReLU has a small negative slope (for example, 0.01). That is, the function computes $f(x) = \mathbb{1}(x < 0) (\alpha x) + \mathbb{1}(x>=0) (x)$ where $\alpha$ is a small constant. Some people report success with this form of activation function, but the results are not always consistent.
#
# The **tanh non-linearity** squashes a real-valued number to the range [-1, 1]. Like the sigmoid neuron, its activations saturate, but unlike the sigmoid neuron its output is zero-centered. Therefore, in practice the tanh non-linearity is always preferred to the sigmoid non-linearity. Also note that the tanh neuron is simply a scaled sigmoid neuron, in particular the following holds: $\tanh(x) = 2 \cdot \sigma(2x) -1$.
#
# <img class=left src=https://pytorch.org/docs/stable/_images/LeakyReLU.png alt="Figure3" width="350" align='left'/>
# <img class=right src=https://pytorch.org/docs/stable/_images/Tanh.png alt="Figure4" width="350"/>
#
# <div class="alert alert-info">
#     <h3>Task: Implement Activation Layers</h3>
#     <p> Now, it is your turn to implement the <code>LeakyRelu</code> and the <code>Tanh</code> class in <code>exercise_code/networks/layer.py</code> by completing the <code>forward</code> and the <code>backward</code> functions. You can test your implementation in the following two cells. </p>
#     <p> <b>Note:</b> Always remember to return a cache in <code>forward</code> for later backpropagation in <code>backward</code>. As we have seen above, the <code>cache</code> variable can be used differently for two activation functions.</p>
# </div>
#
# Use this cell to test your implementation of the `LeakyRelu` class:

# %%
from exercise_code.tests.layer_tests import *
print(LeakyReluTestWrapper()())
# Out:
# LeakyReluForwardTest passed.
# LeakyReluBackwardTest passed.
# Congratulations you have passed all the unit tests!!! Tests passed: 2/2
# Score: 100/100
# You secured a score of :100

# %% [markdown]
# And this cell to test your implementation of the `Tanh` class:

# %%
print(TanhTestWrapper()())
# Out:
# TanhForwardTest passed.
# TanhBackwardTest passed.
# Congratulations you have passed all the unit tests!!! Tests passed: 2/2
# Score: 100/100
# You secured a score of :100

# %% [markdown]
# Congratulations, you now implemented all four different activation functions! These activation layers are now ready to be used when you start building your own network.

# %% [markdown]
# ## 1.4 Loss
#
# In order to measure how well a network is performing, we implemented several ```Loss``` classes (```L1```, ```MSE```, ```BCE```, each preferred for a certain type of problems) in ```exercise_code/networks/loss.py```.
#
# Each implemented a ```forward()``` method, which outputs a number that we use as a proxy for our network performance.
#
# Also, because our goal was to change the weights of the network such that this loss measure decreases, we were also interested in the gradients of the loss w.r.t the outputs of the network, $ \nabla_{\hat{y}} L({\hat{y}}, {y}) $. This was implemented in ```backward()```.
#
# In previous exercises, we only worked with binary classification and used binary cross entropy (```BCE```) as a loss function.
#
# $$ BCE(\hat{y}, y) = \frac{1}{N} \sum_{i=1}^N \Big [-y_i \log(\hat{y_i}) - (1-y_i) \log(1 - \hat{y_i}) \Big] $$
#
# where
# - $ N $ was the number of samples we were considering
# - $\hat{y}_i$ was the network's prediction for sample $i$. Note that this was a valid probability $\in [0, 1]$, because we applied a [sigmoid](https://en.wikipedia.org/wiki/Sigmoid_function) activation on the last layer.
# - $ y_i $ was the ground truth label (0 or 1, depending on the class)
#
# Because we have 10 classes in the CIFAR10 dataset, we need a generalization of the binary cross entropy for multiple classes. This is simply called the cross entropy loss and has the following definition:
#
# $$ CE(\hat{y}, y) = \frac{1}{N} \sum_{i=1}^N \sum_{k=1}^{C} \Big[ -y_{ik} \log(\hat{y}_{ik}) \Big] $$
#
# where:
# - $ N $ is again the number of samples
# - $ C $ is the number of classes
# - $ \hat{y}_{ik} $ is the probability that the model assigns for the $k$th class when the $i$th sample is the input. **Because we don't apply any activation function on the last layer of our network, its outputs for each sample will not be a valid probability distribution over the classes. We call these raw outputs of the network '[logits](https://datascience.stackexchange.com/questions/31041/what-does-logits-in-machine-learning-mean/31045)' and we will apply a [softmax](https://en.wikipedia.org/wiki/Softmax_function) activation in order to obtain a valid probability distribution.**
# - $y_{ik} = 1 $ iff the true label of the $i$th sample is $k$ and 0 otherwise. This is called a [one-hot encoding](https://machinelearningmastery.com/why-one-hot-encode-data-in-machine-learning/).
#
# You can check for yourself that when the number of classes $ C $ is 2, then the binary cross entropy is actually equivalent to the cross entropy.
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>Please check the implementation of the <code>CrossEntropyFromLogits</code> class, which can be found in <code>../exercise_06/exercise_code/networks/loss.py</code>. </p>
# </div>

# %%
loss = CrossEntropyFromLogits()

# %% [markdown]
# Just as with the previous losses we have seen, we can simply get the results of the forward and backward passes as follows:

# %% [markdown]
# ```python
# # y_out is the output of the neural network
# # y_truth is the actual label from the dataset
# loss.forward(y_out, y_truth)
# loss.backward(y_out, y_truth)
# ```

# %% [markdown]
# ## 1.5 Optimizer
#
# Now, knowing the gradient of the loss w.r.t the ouputs of the network, as well as the local gradient for each layer of the network, we can use the chain rule to compute all gradients.
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>We implemented several optimizer classes <code>SGD</code>, <code>Adam</code>, <code>sgd_momentum</code> class that implement different first-order parameter update rules, which can be found in <code>../exercise_06/exercise_code/networks/optimizer.py</code>. </p>
#     <p>The <code>step()</code> method iterates through all the parameters of a model and updates them using the gradient information.</p>
# </div>
#
# What the optimizer is doing, in pseudocode, is the following:
#
# ```python
# for param in model:
#     # Use the gradient to update the weights.
#     update(param)
#
#     # Reset the gradient after each update.
#     param.gradient = 0
# ```
#
# ```SGD``` had the simplest update rule:
# ```python
# def update(param):
#     param = param - learning_rate * param.gradient
# ```
#
# For the more complicated update rules, see ```exercise_code/networks/optimizer.py```

# %% [markdown]
# ## 1.6 Solver
#
# The ```Solver``` is where all the above elements come together: Given a train and a validation dataloader, a model, a loss and an optimizer, it uses the training data to optimize a model in order to get better predictions. We simply call ```train()``` and it does its 'magic' for us!
# ```python
# solver = Solver(model,
#                 dataloaders['train'],
#                 dataloaders['val'],
#                 learning_rate=0.001,
#                 loss_func=MSE(),
#                 optimizer=SGD)
#
# solver.train(epochs=epochs)
# ```
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>Please check out the implementation of <code>train()</code> in <code>../exercise_06/exercise_code/solver.py</code>. </p>
# </div>

# %% [markdown]
# ## 1.7 Weight Regularization
#
# Before we finish this section of recap, we want to take a look at some regularization method that has been introduced in the lecture and that is super helpful to improve robustness of our model. Here, we talk about weight regularization.
#
# Weight regularization has been introduced to you as a method preventing our model from overfitting. Essentially, it is a term (solely depending on the weights of our model) that is added to the final loss and that encodes some preference for a certain set of weights $W$ over others. In the lecture, we compared two weight regularization methods and their respective preference for weight vectors. We made the following observation:
#
# 1. L1 regularization: Enforces sparsity
# 2. L2 regularization: Enforces that weights have similar values
#
# The most common weight regularization method is the L2 regularization. From the observations made in the lecture that makes totally sense - at least when we compare it to the L1 regularization. The L2 regularization penalty in the loss prefers smaller and more diffuse weight vectors and hence the model is encouraged to take into account all input dimensions to small amounts rather than a few input dimensions and very strongly.
#
# When using weight regularization, the loss function is a composition of two parts:
# $$L = \underbrace{\frac{1}{N} \sum_{i} L_i}_{\text{data loss}}  + \underbrace{\lambda R(W)}_{\text{regularization loss}}$$
# The first one being the data loss, which is calculated with the Cross Entropy loss in our model. The second part is called the regularization loss $R(W)$ and is computed in the L2 case as follows:
# $$R(W) = \sum_{k} \sum_{l} w_{k,l}^2$$

# %% [markdown]
# # 2. An overview of hyperparameters

# %% [markdown]
# <img src=https://images.deepai.org/glossary-terms/05c646fe1676490aa0b8cab0732a02b2/hyperparams.png alt=hyperparameter width=700>
#
# A **hyperparameter** is a parameter that is set before the learning process begins. Recall that the parameters of weight matrix and bias vector are learned during the learning process.
#
# The hyperparameters are essential, for they control and affect the whole training and have a great impact on the performance of the model.
#
# Some examples of hyperparameters we have covered in lectures:
# * Network architecture
#     * Choice of activation function
#     * Number of layers
#     * ...
# * Learning rate
# * Number of epochs
# * Batch size
# * Regularization strength
# * Momentum
# * ...

# %% [markdown]
# ## 2.1 Start debugging your own network!

# %% [markdown]
# As already suggested in the lectures, you may always want to start from small and simple architectures, to make sure you are going the right way.
#
# First you may need to overfit a single training sample, then a few batches of training samples, then go deeper with larger neural networks and the whole training data.
#
# Here we always provide a default neural network (i.e. ClassificationNet) with arbitrary number of layers, which is a generalization from a fixed 2-layer neural network in exercise 5. You are welcome to implement your own network, in that case just implement **MyOwnNetwork** in ```exercise_code/networks/classification_net.py```. You can also copy things from ClassficationNet and make a little adjustment to your own network. For either way, just pick a network and comment out the other one, then run the cells below for debugging.
#
# <div class="alert alert-warning">
#     <h3>Note:</h3>
#     <p>Please, make sure you don't modify the ClassificationNet itself so that you can always have a working network to fall back on</p>
#     <p>In order to pass this submissions, you can <b>first stick to the default ClassificationNet implementation without changing any code at all</b>. The goal of this submission is to find reasonable hyperparameters and the parameter options of the ClassificationNet are broad enough.</p>
#     <p>Once you have surpassed the submission goal, you can try to implement additional activation functions in the accompanying notebook, try different weight initializations or other adjustments by writing your own network architecture in the MyOwnNetwork class.</p>
# </div>

# %% [markdown]
# First, let's begin with a 2-layer neural network, and overfit one single training sample.
#
# After training, let's evaluate the training process by plotting the loss curves.

# %%
from exercise_code.solver import Solver
from exercise_code.networks.optimizer import SGD, Adam
from exercise_code.networks import MyOwnNetwork

num_layer = 2
epochs = 20
reg = 0.1
batch_size = 4

#model = ClassificationNet(num_layer=num_layer, reg=reg)
model = MyOwnNetwork(num_layer=num_layer, reg=reg)

loss = CrossEntropyFromLogits()

# Make a new data loader with a single training image
overfit_dataset = ImageFolderDataset(
    mode='train',
    root=cifar_root, 
    download_url=download_url,
    transform=compose_transform,
    limit_files=1
)
dataloaders['train_overfit_single_image'] = DataLoader(
    dataset=overfit_dataset,
    batch_size=batch_size,
    shuffle=True,
    drop_last=False,
)

# Decrease validation data for only debugging
debugging_validation_dataset = ImageFolderDataset(
    mode='val',
    root=cifar_root, 
    download_url=download_url,
    transform=compose_transform,
    limit_files=100
)
dataloaders['val_500files'] = DataLoader(
    dataset=debugging_validation_dataset,
    batch_size=batch_size,
    shuffle=True,
    drop_last=True,
)

solver = Solver(model, dataloaders['train_overfit_single_image'], dataloaders['val_500files'], 
                learning_rate=1e-3, loss_func=loss, optimizer=Adam)

solver.train(epochs=epochs)
# Out:
# (Epoch 1 / 20) train loss: 2.327992; val loss: 2.333577
# (Epoch 2 / 20) train loss: 2.327992; val loss: 2.320803
# (Epoch 3 / 20) train loss: 2.201901; val loss: 2.329869
# (Epoch 4 / 20) train loss: 2.052337; val loss: 2.355061
# (Epoch 5 / 20) train loss: 1.881469; val loss: 2.387624
# (Epoch 6 / 20) train loss: 1.711020; val loss: 2.419109
# (Epoch 7 / 20) train loss: 1.556224; val loss: 2.443894
# (Epoch 8 / 20) train loss: 1.413779; val loss: 2.460766
# (Epoch 9 / 20) train loss: 1.277494; val loss: 2.472060
# (Epoch 10 / 20) train loss: 1.146821; val loss: 2.481483
# (Epoch 11 / 20) train loss: 1.022606; val loss: 2.492313
# (Epoch 12 / 20) train loss: 0.906329; val loss: 2.506576
# (Epoch 13 / 20) train loss: 0.800357; val loss: 2.524869
# (Epoch 14 / 20) train loss: 0.706310; val loss: 2.546673
# (Epoch 15 / 20) train loss: 0.624434; val loss: 2.571004
# (Epoch 16 / 20) train loss: 0.553740; val loss: 2.596932
# (Epoch 17 / 20) train loss: 0.492828; val loss: 2.623857
# (Epoch 18 / 20) train loss: 0.440498; val loss: 2.651549
# (Epoch 19 / 20) train loss: 0.395530; val loss: 2.680034
# (Epoch 20 / 20) train loss: 0.356914; val loss: 2.709408

# %%
plt.title('Loss curves')
plt.plot(solver.train_loss_history, '-', label='train')
plt.plot(solver.val_loss_history, '-', label='val')
plt.legend(loc='lower right')
plt.xlabel('Iteration')
plt.show()

# %%
print("Training accuray: %.5f" % (solver.get_dataset_accuracy(dataloaders['train_overfit_single_image'])))
print("Validation accuray: %.5f" % (solver.get_dataset_accuracy(dataloaders['val_500files'])))
# Out:
# Training accuray: 1.00000
# Validation accuray: 0.07000

# %% [markdown]
# This time let's try to overfit to a small set of training batch samples. Please observe the difference from above.

# %%
from exercise_code.networks import MyOwnNetwork

num_layer = 2
epochs = 100
reg = 0.1
num_samples = 10

#model = ClassificationNet(num_layer=num_layer, reg=reg)
model = MyOwnNetwork(num_layer=num_layer, reg=reg)

loss = CrossEntropyFromLogits()

# Make a new data loader with a our num_samples training image
overfit_dataset = ImageFolderDataset(
    mode='train',
    root=cifar_root, 
    download_url=download_url,
    transform=compose_transform,
    limit_files=num_samples
)
dataloaders['train_overfit_10samples'] = DataLoader(
    dataset=overfit_dataset,
    batch_size=batch_size,
    shuffle=True,
    drop_last=False,
)

solver = Solver(model, dataloaders['train_overfit_10samples'], dataloaders['val_500files'], 
                learning_rate=1e-3, loss_func=loss, optimizer=Adam)

solver.train(epochs=epochs)
# Out:
# (Epoch 1 / 100) train loss: 2.331938; val loss: 2.334331
# (Epoch 2 / 100) train loss: 2.325609; val loss: 2.337541
# (Epoch 3 / 100) train loss: 2.207519; val loss: 2.391639
# (Epoch 4 / 100) train loss: 2.048381; val loss: 2.439445
# (Epoch 5 / 100) train loss: 2.048479; val loss: 2.522273
# (Epoch 6 / 100) train loss: 1.925998; val loss: 2.566617
# (Epoch 7 / 100) train loss: 1.857588; val loss: 2.628791
# (Epoch 8 / 100) train loss: 1.725757; val loss: 2.711391
# (Epoch 9 / 100) train loss: 1.752357; val loss: 2.795958
# (Epoch 10 / 100) train loss: 1.810925; val loss: 2.842225
# (Epoch 11 / 100) train loss: 1.718056; val loss: 2.855684
# (Epoch 12 / 100) train loss: 1.646908; val loss: 2.979115
# (Epoch 13 / 100) train loss: 1.625130; val loss: 3.089495
# (Epoch 14 / 100) train loss: 1.672408; val loss: 3.119818
# (Epoch 15 / 100) train loss: 1.598648; val loss: 3.084452
# (Epoch 16 / 100) train loss: 1.674407; val loss: 3.100027
# (Epoch 17 / 100) train loss: 1.714083; val loss: 3.168348
# (Epoch 18 / 100) train loss: 1.656148; val loss: 3.252408
# (Epoch 19 / 100) train loss: 1.739993; val loss: 3.245475
# (Epoch 20 / 100) train loss: 1.561257; val loss: 3.253790
# (Epoch 21 / 100) train loss: 1.540376; val loss: 3.314405
# (Epoch 22 / 100) train loss: 1.646614; val loss: 3.308773
# (Epoch 23 / 100) train loss: 1.581151; val loss: 3.302904
# (Epoch 24 / 100) train loss: 1.422976; val loss: 3.371343
# (Epoch 25 / 100) train loss: 1.562293; val loss: 3.425782
# (Epoch 26 / 100) train loss: 1.647568; val loss: 3.397219
# (Epoch 27 / 100) train loss: 1.467402; val loss: 3.377734
# (Epoch 28 / 100) train loss: 1.495070; val loss: 3.354369
# (Epoch 29 / 100) train loss: 1.588650; val loss: 3.382466
# (Epoch 30 / 100) train loss: 1.483492; val loss: 3.407889
# (Epoch 31 / 100) train loss: 1.515264; val loss: 3.393643
# (Epoch 32 / 100) train loss: 1.466285; val loss: 3.401993
# (Epoch 33 / 100) train loss: 1.423159; val loss: 3.425434
# (Epoch 34 / 100) train loss: 1.400972; val loss: 3.430258
# (Epoch 35 / 100) train loss: 1.348053; val loss: 3.429814
# (Epoch 36 / 100) train loss: 1.329759; val loss: 3.433689
# (Epoch 37 / 100) train loss: 1.288834; val loss: 3.455196
# (Epoch 38 / 100) train loss: 1.348734; val loss: 3.464836
# (Epoch 39 / 100) train loss: 1.260980; val loss: 3.498036
# (Epoch 40 / 100) train loss: 1.358767; val loss: 3.473409
# (Epoch 41 / 100) train loss: 1.390493; val loss: 3.433425
# (Epoch 42 / 100) train loss: 1.292045; val loss: 3.491149
# (Epoch 43 / 100) train loss: 1.268652; val loss: 3.539978
# (Epoch 44 / 100) train loss: 1.330824; val loss: 3.513853
# (Epoch 45 / 100) train loss: 1.287729; val loss: 3.509725
# (Epoch 46 / 100) train loss: 1.290267; val loss: 3.519821
# (Epoch 47 / 100) train loss: 1.172291; val loss: 3.522474
# (Epoch 48 / 100) train loss: 1.195694; val loss: 3.491398
# (Epoch 49 / 100) train loss: 1.170439; val loss: 3.480601
# (Epoch 50 / 100) train loss: 1.119711; val loss: 3.482389
# (Epoch 51 / 100) train loss: 1.257560; val loss: 3.513039
# (Epoch 52 / 100) train loss: 1.181583; val loss: 3.600747
# (Epoch 53 / 100) train loss: 1.283340; val loss: 3.644795
# (Epoch 54 / 100) train loss: 1.265615; val loss: 3.624526
# (Epoch 55 / 100) train loss: 1.159158; val loss: 3.576834
# (Epoch 56 / 100) train loss: 1.182414; val loss: 3.551872
# (Epoch 57 / 100) train loss: 1.105850; val loss: 3.560429
# (Epoch 58 / 100) train loss: 1.130616; val loss: 3.571432
# (Epoch 59 / 100) train loss: 1.134558; val loss: 3.574873
# (Epoch 60 / 100) train loss: 1.027422; val loss: 3.568672
# (Epoch 61 / 100) train loss: 1.027777; val loss: 3.541614
# (Epoch 62 / 100) train loss: 1.071632; val loss: 3.526807
# (Epoch 63 / 100) train loss: 1.000724; val loss: 3.545189
# (Epoch 64 / 100) train loss: 1.001871; val loss: 3.569452
# (Epoch 65 / 100) train loss: 1.005035; val loss: 3.568322
# (Epoch 66 / 100) train loss: 1.012345; val loss: 3.581639
# (Epoch 67 / 100) train loss: 1.031481; val loss: 3.623874
# (Epoch 68 / 100) train loss: 1.022743; val loss: 3.655385
# (Epoch 69 / 100) train loss: 1.002597; val loss: 3.638895
# (Epoch 70 / 100) train loss: 1.047481; val loss: 3.595655
# (Epoch 71 / 100) train loss: 1.074237; val loss: 3.591181
# (Epoch 72 / 100) train loss: 1.023344; val loss: 3.627247
# (Epoch 73 / 100) train loss: 0.985536; val loss: 3.649597
# (Epoch 74 / 100) train loss: 0.956673; val loss: 3.626058
# (Epoch 75 / 100) train loss: 0.953968; val loss: 3.563884
# (Epoch 76 / 100) train loss: 0.932819; val loss: 3.543700
# (Epoch 77 / 100) train loss: 0.907463; val loss: 3.561685
# (Epoch 78 / 100) train loss: 0.920114; val loss: 3.581150
# (Epoch 79 / 100) train loss: 0.902032; val loss: 3.603120
# (Epoch 80 / 100) train loss: 0.899427; val loss: 3.566424
# (Epoch 81 / 100) train loss: 0.928899; val loss: 3.577112
# (Epoch 82 / 100) train loss: 0.924480; val loss: 3.587221
# (Epoch 83 / 100) train loss: 0.964044; val loss: 3.580696
# (Epoch 84 / 100) train loss: 0.874808; val loss: 3.583204
# (Epoch 85 / 100) train loss: 0.938830; val loss: 3.587788
# (Epoch 86 / 100) train loss: 0.853180; val loss: 3.594803
# (Epoch 87 / 100) train loss: 0.909091; val loss: 3.579225
# (Epoch 88 / 100) train loss: 0.899377; val loss: 3.540678
# (Epoch 89 / 100) train loss: 0.877273; val loss: 3.561657
# (Epoch 90 / 100) train loss: 0.851209; val loss: 3.592029
# (Epoch 91 / 100) train loss: 0.860576; val loss: 3.592714
# (Epoch 92 / 100) train loss: 0.917568; val loss: 3.586197
# (Epoch 93 / 100) train loss: 0.916384; val loss: 3.648954
# (Epoch 94 / 100) train loss: 1.027391; val loss: 3.628603
# (Epoch 95 / 100) train loss: 0.898212; val loss: 3.659187
# (Epoch 96 / 100) train loss: 0.937496; val loss: 3.673554
# (Epoch 97 / 100) train loss: 0.982593; val loss: 3.657673
# (Epoch 98 / 100) train loss: 0.895751; val loss: 3.655952
# (Epoch 99 / 100) train loss: 0.840275; val loss: 3.596174
# (Epoch 100 / 100) train loss: 0.906998; val loss: 3.558889

# %%
plt.title('Loss curves')
plt.plot(solver.train_loss_history, '-', label='train')
plt.plot(solver.val_loss_history, '-', label='val')
plt.legend(loc='lower right')
plt.xlabel('Iteration')
plt.show()

# %%
print("Training accuray: %.5f" % (solver.get_dataset_accuracy(dataloaders['train_overfit_10samples'])))
print("Validation accuray: %.5f" % (solver.get_dataset_accuracy(dataloaders['val_500files'])))
# Out:
# Training accuray: 1.00000
# Validation accuray: 0.06000

# %% [markdown]
# If you're overfitting the training data, that means the network's implementation is correct. However, as you have more samples to overfit, your accuracy will be way lower. You can increase the number of epochs above to achieve better results.
#
# Now let's try to feed all the training and validation data into the network, but this time we set the same hyperparameters for 2-layer and 5-layer networks, and compare the different behaviors.
#
# <div class="alert alert-warning">
#     <h3>Note:</h3>
#     <p>This may take about 1 min for each epoch as the training set is quite large. For convenience, we only train on 1000 images for now but use the full validation set.</p>
# </div>

# %%
from exercise_code.networks import MyOwnNetwork

num_layer = 2
epochs = 5
reg = 0.01

# Make a new data loader with 1000 training samples
num_samples = 1000
overfit_dataset = ImageFolderDataset(
    mode='train',
    root=cifar_root, 
    download_url=download_url,
    transform=compose_transform,
    limit_files=num_samples
)
dataloaders['train_small'] = DataLoader(
    dataset=overfit_dataset,
    batch_size=batch_size,
    shuffle=True,
    drop_last=False,
)


# Change here if you want to use the full training set
use_full_training_set = False
if not use_full_training_set:
    train_loader = dataloaders['train_small']
else:
    train_loader = dataloaders['train']
    

#model = ClassificationNet(num_layer=num_layer, reg=reg)
model = MyOwnNetwork(num_layer=num_layer, reg=reg)

loss = CrossEntropyFromLogits()

solver = Solver(model, train_loader, dataloaders['val'], 
                learning_rate=1e-3, loss_func=loss, optimizer=Adam)

solver.train(epochs=epochs)
# Out:
# (Epoch 1 / 5) train loss: 2.305701; val loss: 2.305666
# (Epoch 2 / 5) train loss: 2.278313; val loss: 2.217917
# (Epoch 3 / 5) train loss: 2.229720; val loss: 2.238025
# (Epoch 4 / 5) train loss: 2.225433; val loss: 2.224318
# (Epoch 5 / 5) train loss: 2.221445; val loss: 2.223965

# %%
plt.title('Loss curves')
plt.plot(solver.train_loss_history, '-', label='train')
plt.plot(solver.val_loss_history, '-', label='val')
plt.legend(loc='lower right')
plt.xlabel('Iteration')
plt.show()

# %%
print("Training accuray: %.5f" % (solver.get_dataset_accuracy(train_loader)))
print("Validation accuray: %.5f" % (solver.get_dataset_accuracy(dataloaders['val'])))
# Out:
# Training accuray: 0.31300
# Validation accuray: 0.25551

# %%
from exercise_code.networks import MyOwnNetwork

num_layer = 5
epochs = 5
reg = 0.01

#model = ClassificationNet(num_layer=num_layer, reg=reg)
model = MyOwnNetwork(num_layer=num_layer, reg=reg)

# Change here if you want to use the full training set
use_full_training_set = False
if not use_full_training_set:
    train_loader = dataloaders['train_small']
else:
    train_loader = dataloaders['train']

loss = CrossEntropyFromLogits()

solver = Solver(model, train_loader, dataloaders['val'], 
                learning_rate=1e-3, loss_func=loss, optimizer=Adam)

solver.train(epochs=epochs)
# Out:
# (Epoch 1 / 5) train loss: 2.305912; val loss: 2.305979
# (Epoch 2 / 5) train loss: 2.327428; val loss: 2.308302
# (Epoch 3 / 5) train loss: 2.318951; val loss: 2.320646
# (Epoch 4 / 5) train loss: 2.313579; val loss: 2.323224
# (Epoch 5 / 5) train loss: 2.318441; val loss: 2.314183

# %%
plt.title('Loss curves')
plt.plot(solver.train_loss_history, '-', label='train')
plt.plot(solver.val_loss_history, '-', label='val')
plt.legend(loc='lower right')
plt.xlabel('Iteration')
plt.show()

# %%
print("Training accuray: %.5f" % (solver.get_dataset_accuracy(train_loader)))
print("Validation accuray: %.5f" % (solver.get_dataset_accuracy(dataloaders['val'])))
# Out:
# Training accuray: 0.10500
# Validation accuray: 0.09826

# %% [markdown]
# As you can see from above, the same hyperparameter set can decrease the loss for a 2-layer network, but for 5-layer network, it hardly works.
#
# The steps above are already mentioned in the lectures as debugging steps before training a neural network.
#
# If you implement your own network, make sure you do the steps above before tuning the hyperparameters as below.

# %% [markdown]
# ## 2.2 Difficulty in tuning hyperparameters
# As can be seen through the results of training a larger network, training with whole data doesn't fit the training data as well as training with small number of training data. Besides, the architecture of neural network makes a difference, too. Small decisions on hyperparameters count.
#
# Usually, but not always, hyperparameters cannot be learned using well known gradient based methods (such as gradient descent), which are commonly employed to learn parameters. Besides, some hyperparameters can affect the structure of the model and the loss function.
#
# As mentioned before, hyperparameters need to be set before training. Tuning hyperparameters is hard, because you always have to try different combinations of the hyperparameters, train the network, do the validation and pick the best one. Besides, it is not guaranteed that you'll find the best combination.
#
# Next you will do hands on learning with hyperparameter tuning methods that are covered in lectures.

# %% [markdown]
# # 3. Hyperparameter Tuning
#
# ![alt text](https://blog.floydhub.com/content/images/2018/08/Screen-Shot-2018-08-22-at-17.59.25.png "")
#
# One of the main challenges in deep learning is finding the set of hyperparameters that performs best.
#
# So far, we have followed a manual approach by guessing hyperparameters, running the model, observing the result and maybe tweaking the hyperparameters based on this result. As you have probably noticed, this manual hyperparameter tuning is unstructured, inefficient and can become very tedious.
#
#
# A more systematic (and actually very simple) approach for hyperparameter tuning that you've already learned in the lecture  is implementing a **Grid Search**.
#
#
#
# ## 3.1 Grid Search
# Grid search is a simple and naive, yet effective method to automate the hyperparameter tuning:
#
# * First, you define the set of parameters you want to tune, e.g. $\{learning\_rate, regularization\_strength\}$.
#
# * For each hyperparameter, you then define a set of possible values, e.g. $learning\_rate = \{0.0001, 0.001, 0.01, 0.1\}$.
#
# * Then, you train a model for every possible combination of these hyperparameter values and afterwards select the combination that works best (e.g. in terms of accuracy on your validation set).
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>Check out our <code>grid_search</code> implementation in <code>../exercise_6/exercise_code/hyperparameter_tuning.py</code>. We show a simple for loop implementation and a more sophisticated one for multiple inputs. </p>
# </div>
#
#  <div class="alert alert-warning">
#     <h3>Note:</h3>
#     <p>To keep things simple for the beginning, it'll be enough to just focus on the hyperparameters <code>learning_rate</code> and <code>regularization_strength</code> here, as in the example above.</p>
# </div>

# %%
from exercise_code.networks import MyOwnNetwork

# Specify the used network
model_class = ClassificationNet

from exercise_code import hyperparameter_tuning
best_model, results = hyperparameter_tuning.grid_search(
    dataloaders['train_small'], dataloaders['val_500files'],
    grid_search_spaces = {
        "learning_rate": [1e-2, 1e-3, 1e-4], 
        "reg": [1e-4]
    },
    model_class=model_class,
    epochs=10, patience=5)
# Out:
# Evaluating Config #1 [of 3]:
#  {'learning_rate': 0.01, 'reg': 0.0001}
# (Epoch 1 / 10) train loss: 2.302778; val loss: 2.302379
# (Epoch 2 / 10) train loss: 2.554652; val loss: 2.517560
# (Epoch 3 / 10) train loss: 2.776706; val loss: 2.869247
# (Epoch 4 / 10) train loss: 2.911897; val loss: 3.074301
# (Epoch 5 / 10) train loss: 3.071861; val loss: 3.144430
# /home/jamesqian/Documents/DeepVision/HW6/exercise_code/networks/layer.py:66: RuntimeWarning: overflow encountered in exp
#   outputs = 1 / (1 + np.exp(-x))
# (Epoch 6 / 10) train loss: 3.159838; val loss: 3.099358
# Stopping early at epoch 5!
#
# Evaluating Config #2 [of 3]:
#  {'learning_rate': 0.001, 'reg': 0.0001}
# (Epoch 1 / 10) train loss: 2.302776; val loss: 2.302850
# (Epoch 2 / 10) train loss: 2.188627; val loss: 2.018576
# (Epoch 3 / 10) train loss: 1.999532; val loss: 1.933551
# (Epoch 4 / 10) train loss: 1.898786; val loss: 1.913171
# (Epoch 5 / 10) train loss: 1.842671; val loss: 1.900585
# (Epoch 6 / 10) train loss: 1.768754; val loss: 1.895444
# (Epoch 7 / 10) train loss: 1.708299; val loss: 1.963242
# (Epoch 8 / 10) train loss: 1.637845; val loss: 1.924719
# (Epoch 9 / 10) train loss: 1.589401; val loss: 1.937371
# (Epoch 10 / 10) train loss: 1.532186; val loss: 1.898820
#
# Evaluating Config #3 [of 3]:
#  {'learning_rate': 0.0001, 'reg': 0.0001}
# (Epoch 1 / 10) train loss: 2.302742; val loss: 2.302700
# (Epoch 2 / 10) train loss: 2.286272; val loss: 2.243366
# (Epoch 3 / 10) train loss: 2.212058; val loss: 2.153702
# (Epoch 4 / 10) train loss: 2.136847; val loss: 2.086200
# (Epoch 5 / 10) train loss: 2.075843; val loss: 2.034195
# (Epoch 6 / 10) train loss: 2.025140; val loss: 1.996724
# (Epoch 7 / 10) train loss: 1.980983; val loss: 1.980872
# (Epoch 8 / 10) train loss: 1.941590; val loss: 1.947735
# (Epoch 9 / 10) train loss: 1.904624; val loss: 1.928624
# (Epoch 10 / 10) train loss: 1.870713; val loss: 1.909161
#
# Search done. Best Val Loss = 1.8954439558202578
# Best Config: {'learning_rate': 0.001, 'reg': 0.0001}

# %% [markdown]
# From the results of your grid search, you might already have found some hyperparameter combinations that work better than others. A common practice is to now repeat the grid search on a more narrow domain centered around the parameters that worked best.
#
# **Conclusion Grid Search**
#
# With grid search we now have automated the hyperparameter tuning to a certain degree. Another advantage is, that since the training of all models are independent of each other, you can parallelize the grid search, i.e.,  try out different hyperparameter configurations in parallel on different machines.
#
# However, as you have probably noticed, there is one big problem with this approach: the number of possible combinations to try out grows exponentially with the number of hyperparameters ("curse of dimensionality"). As we add more hyperparameters to the grid search, the search space will explode in time complexity, making this strategy unfeasible.

# %% [markdown]
# Especially when your search space contains more than 3 or 4 dimensions, it is often better to use another, similar hyperparameter tuning method that you've already learned about: random search.

# %% [markdown]
# ## 3.2 Random Search
# Random search is very similar to grid search, with the only difference, that instead of providing specific values for every hyperparameter, you only define a range for each hyperparameter - then, the values are sampled randomly from the provided ranges.
#
# ![alt text](https://i.stack.imgur.com/cIDuR.png "")
#
# The figure above illustrates the difference in the hyperparameter space exploration between grid search and random search: assume you have 2 hyperparameters with each 3 values. Running a grid search results in training $3^2=9$ different models - but in the end, you've just tired out 3 values for each parameter. For random search on the other hand, after training 9 models you'll have tried out 9 different values for each hyperparameter, which often leads much faster to good results.
#
# To get a deeper understanding of random search and why it is more efficient than grid search, you should definitely check out this paper: http://www.jmlr.org/papers/volume13/bergstra12a/bergstra12a.pdf
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>Check out our <code>random_search</code> implementation in <code>../exercise_6/exercise_code/hyperparameter_tuning.py</code></p>
# </div>
#
#
# *Hint: regarding the sample space of each parameter, think about the scale for which it makes most sense to sample in. For example the learning rate is usually sampled on a logarithmic scale!*
#
# *For simplicity and speed, just use the `train_batches`-dataloader!*

# %%
from exercise_code.hyperparameter_tuning import random_search
from exercise_code.networks import MyOwnNetwork

# Specify the used network
model_class = ClassificationNet

best_model, results = random_search(
    dataloaders['train_small'], dataloaders['val_500files'],
    random_search_spaces = {
        "learning_rate": ([1e-2, 1e-6], 'log'),
        "reg": ([1e-3, 1e-7], "log"),
        "loss_func": ([CrossEntropyFromLogits()], "item")
    },
    model_class=model_class,
    num_search = 1, epochs=20, patience=5)
# Out:
# Evaluating Config #1 [of 1]:
#  {'learning_rate': 7.012351530782426e-06, 'reg': 5.697755511199378e-07, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed58f370>}
# (Epoch 1 / 20) train loss: 2.302915; val loss: 2.302397
# (Epoch 2 / 20) train loss: 2.302430; val loss: 2.301057
# (Epoch 3 / 20) train loss: 2.300705; val loss: 2.299548
# (Epoch 4 / 20) train loss: 2.298561; val loss: 2.297230
# (Epoch 5 / 20) train loss: 2.295811; val loss: 2.294180
# (Epoch 6 / 20) train loss: 2.292313; val loss: 2.290159
# (Epoch 7 / 20) train loss: 2.288079; val loss: 2.285222
# (Epoch 8 / 20) train loss: 2.283241; val loss: 2.279698
# (Epoch 9 / 20) train loss: 2.277868; val loss: 2.273646
# (Epoch 10 / 20) train loss: 2.272126; val loss: 2.266631
# (Epoch 11 / 20) train loss: 2.266063; val loss: 2.259841
# (Epoch 12 / 20) train loss: 2.259914; val loss: 2.252599
# (Epoch 13 / 20) train loss: 2.253574; val loss: 2.245565
# (Epoch 14 / 20) train loss: 2.247240; val loss: 2.237999
# (Epoch 15 / 20) train loss: 2.240786; val loss: 2.230861
# (Epoch 16 / 20) train loss: 2.234309; val loss: 2.223410
# (Epoch 17 / 20) train loss: 2.227879; val loss: 2.216253
# (Epoch 18 / 20) train loss: 2.221518; val loss: 2.209110
# (Epoch 19 / 20) train loss: 2.215165; val loss: 2.202054
# (Epoch 20 / 20) train loss: 2.208868; val loss: 2.195344
#
# Search done. Best Val Loss = 2.19534401735675
# Best Config: {'learning_rate': 7.012351530782426e-06, 'reg': 5.697755511199378e-07, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed58f370>}

# %% [markdown]
# It's time to run it with the whole dataset, and let it search for a few hours for a nice configuration.
#
# However, to save some time, let's first implement an **early-stopping** mechanism, that you also already know from the lecture.

# %% [markdown]
# ## 3.3 Early Stopping

# %% [markdown]
# By now you've already seen a lot of training curves:
#
# <img src=http://fouryears.eu/wp-content/uploads/2017/12/early_stopping.png></img>
#
# Usually, at some point the validation loss goes up again, which is a sign that we're overfitting to our training data. Since it actually doesn't make any sense to train further at this point, it's common practice to apply "early stopping", i.e., cancel the training process when the validation loss doesn't improve anymore. The nice thing about this concept is, that not only it improves generalization through the prevention of overfitting, but also it saves us a lot of time - one of our most valuable resources in deep learning.
#
# Since there are natural fluctuations in the validation loss, you usually don't cancel the training process right at the first epoch when the validation-loss increases, but instead, you wait for some epochs (specified by the `patience`-parameter) and if the loss still doesn't improve, we stop.
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>Please check the implementation of the early stopping mechanism in <code>../exercise_6/exercise_code/solver.py</code>.
#  </p>
# </div>

# %% [markdown]
# ## 3.4 Let's find the perfect model!

# %% [markdown]
# You've now set everything up to start training your model and finding a nice set of hyper parameters using a combination of grid or random search!
#
# Since we'll now be training with a much larger number of samples, you should be aware that this process will definitely take some time! So be prepared to let your machine run for a while.
#
# At the beginning, it's a good approach to first do a coarse random search across a wide range of values to find promising sub-ranges of your parameter space. Afterwards, you can zoom in to these ranges and do another random search (or grid search) to finetune the configuration.
#
# You don't have to use the whole dataset at the beginning, instead you can also use a medium large subset of the samples. Also, you don't need to train for a large number of epochs - as mentioned above: we first want to get an overview about our hyper parameters.
#
# <div class="alert alert-info">
#     <h3>Task: Hyperparameters Tunning & Model Training </h3>
#         <p> Now, it is your turn to do the hyperparamater tuning. In the cell below, you can use the <code>random_search</code> function to find a good choice of parameters. Put in some reasonable ranges for the hyperparameters and evaluate them.
#     <p> <b>Note:</b> At the beginning, it's a good approach to first do a coarse random search across a <b> wide range of values</b> to find promising sub-ranges of your parameter space and use <b> a medium large subset of the dataset </b>instead the whole as well. Afterwards, you can zoom in to these ranges and do another random search (or grid search) to finetune the configuration. Use the cell below to play around and find good hyperparameters for your model!</p>
#         <p> Finally, once you've found some promising hyperparameters (or narrowed them down to promising subranges), it's time to utilize these hyperparameters to train your network on the whole dataset for a large number of epochs so that your own model can reach an acceptable performance.
#         <p> <b>Hint:</b> You may use a <code>Solver</code> class we provided before or directly use the <code>random_search</code> function (as you can also monitor the loss here) for model training.
# </div>

# %%
from exercise_code.networks import MyOwnNetwork

#best_model = ClassificationNet()
best_model = MyOwnNetwork()

########################################################################
# TODO:                                                                #
# Implement your own neural network and find suitable hyperparameters  #
# Be sure to edit the MyOwnNetwork class in the following code snippet #
# to upload the correct model!                                         #
########################################################################


batch_size = 1024
overfit_dataset = ImageFolderDataset(
    mode='train',
    root=cifar_root, 
    download_url=download_url,
    transform=compose_transform
)
dataloaders['train'] = DataLoader(
    dataset=overfit_dataset,
    batch_size=batch_size,
    shuffle=True,
    drop_last=False,
)

best_model, results = random_search(
    dataloaders['train'], dataloaders['val_500files'],
    random_search_spaces = {
        "learning_rate": ([1e-2, 1e-5], 'log'),
        "reg": ([1e-2, 1e-8], "log"),
        "loss_func": ([CrossEntropyFromLogits()], "item")
    },
    model_class=model_class,
    num_search = 30, epochs = 20, patience = 5)

print('\n\n')

epochs = 100
best_model.reg_strength = results[0][0]['reg']
rate = results[0][0]['learning_rate']
train_loader = dataloaders['train']
loss = CrossEntropyFromLogits()

solver = Solver(best_model, train_loader, dataloaders['val'], 
                learning_rate=rate, loss_func=loss, optimizer=Adam)

solver.train(epochs=epochs, patience=75)

plt.title('Loss curves')
plt.plot(solver.train_loss_history, '-', label='train')
plt.plot(solver.val_loss_history, '-', label='val')
plt.legend(loc='lower right')
plt.xlabel('Iteration')
plt.show()

########################################################################
#                           END OF YOUR CODE                           #
########################################################################
# Out:
# Evaluating Config #1 [of 30]:
#  {'learning_rate': 0.003520351878343782, 'reg': 0.0019771089426522917, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed55f940>}
# (Epoch 1 / 20) train loss: 2.303203; val loss: 2.302972
# (Epoch 2 / 20) train loss: 2.076446; val loss: 1.926695
# (Epoch 3 / 20) train loss: 1.884956; val loss: 1.781248
# (Epoch 4 / 20) train loss: 1.828163; val loss: 1.760124
# (Epoch 5 / 20) train loss: 1.806225; val loss: 1.752242
# (Epoch 6 / 20) train loss: 1.786982; val loss: 1.772544
# (Epoch 7 / 20) train loss: 1.786269; val loss: 1.778940
# (Epoch 8 / 20) train loss: 1.780062; val loss: 1.784075
# (Epoch 9 / 20) train loss: 1.776943; val loss: 1.760337
# (Epoch 10 / 20) train loss: 1.761393; val loss: 1.765694
# Stopping early at epoch 9!
#
# Evaluating Config #2 [of 30]:
#  {'learning_rate': 0.004307594224602966, 'reg': 2.6965263690734664e-08, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed55f940>}
# (Epoch 1 / 20) train loss: 2.302607; val loss: 2.302394
# (Epoch 2 / 20) train loss: 2.033779; val loss: 1.827728
# (Epoch 3 / 20) train loss: 1.804378; val loss: 1.702459
# (Epoch 4 / 20) train loss: 1.714899; val loss: 1.690065
# (Epoch 5 / 20) train loss: 1.658161; val loss: 1.667450
# (Epoch 6 / 20) train loss: 1.612159; val loss: 1.647039
# (Epoch 7 / 20) train loss: 1.576467; val loss: 1.691397
# (Epoch 8 / 20) train loss: 1.547467; val loss: 1.623940
# (Epoch 9 / 20) train loss: 1.517630; val loss: 1.622001
# (Epoch 10 / 20) train loss: 1.486841; val loss: 1.622220
# (Epoch 11 / 20) train loss: 1.459904; val loss: 1.601410
# (Epoch 12 / 20) train loss: 1.428225; val loss: 1.648860
# (Epoch 13 / 20) train loss: 1.411128; val loss: 1.648878
# (Epoch 14 / 20) train loss: 1.386678; val loss: 1.578345
# (Epoch 15 / 20) train loss: 1.354979; val loss: 1.532769
# (Epoch 16 / 20) train loss: 1.338323; val loss: 1.653887
# (Epoch 17 / 20) train loss: 1.324816; val loss: 1.635021
# (Epoch 18 / 20) train loss: 1.287286; val loss: 1.611139
# (Epoch 19 / 20) train loss: 1.268267; val loss: 1.648697
# (Epoch 20 / 20) train loss: 1.249366; val loss: 1.660526
# Stopping early at epoch 19!
#
# Evaluating Config #3 [of 30]:
#  {'learning_rate': 0.008210581561175335, 'reg': 2.5061667303597616e-06, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed55f940>}
# (Epoch 1 / 20) train loss: 2.302633; val loss: 2.302862
# (Epoch 2 / 20) train loss: 2.028480; val loss: 1.808903
# (Epoch 3 / 20) train loss: 1.797306; val loss: 1.727250
# (Epoch 4 / 20) train loss: 1.718724; val loss: 1.695760
# (Epoch 5 / 20) train loss: 1.673930; val loss: 1.729446
# (Epoch 6 / 20) train loss: 1.650734; val loss: 1.703528
# (Epoch 7 / 20) train loss: 1.618627; val loss: 1.682169
# (Epoch 8 / 20) train loss: 1.595508; val loss: 1.671044
# (Epoch 9 / 20) train loss: 1.577460; val loss: 1.670108
# (Epoch 10 / 20) train loss: 1.555812; val loss: 1.599190
# (Epoch 11 / 20) train loss: 1.545195; val loss: 1.643880
# (Epoch 12 / 20) train loss: 1.525713; val loss: 1.601950
# (Epoch 13 / 20) train loss: 1.511788; val loss: 1.693106
# (Epoch 14 / 20) train loss: 1.504145; val loss: 1.569693
# (Epoch 15 / 20) train loss: 1.480951; val loss: 1.591598
# (Epoch 16 / 20) train loss: 1.466714; val loss: 1.640800
# (Epoch 17 / 20) train loss: 1.462566; val loss: 1.625006
# (Epoch 18 / 20) train loss: 1.451532; val loss: 1.615179
# (Epoch 19 / 20) train loss: 1.440709; val loss: 1.565731
# (Epoch 20 / 20) train loss: 1.432614; val loss: 1.640727
#
# Evaluating Config #4 [of 30]:
#  {'learning_rate': 2.402728349027576e-05, 'reg': 4.900979518415221e-05, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed55f940>}
# (Epoch 1 / 20) train loss: 2.302605; val loss: 2.303085
# (Epoch 2 / 20) train loss: 2.302268; val loss: 2.300794
# (Epoch 3 / 20) train loss: 2.300884; val loss: 2.298426
# (Epoch 4 / 20) train loss: 2.297788; val loss: 2.292703
# (Epoch 5 / 20) train loss: 2.291837; val loss: 2.282701
# (Epoch 6 / 20) train loss: 2.282563; val loss: 2.268976
# (Epoch 7 / 20) train loss: 2.270960; val loss: 2.252482
# (Epoch 8 / 20) train loss: 2.258118; val loss: 2.234827
# (Epoch 9 / 20) train loss: 2.245138; val loss: 2.216841
# (Epoch 10 / 20) train loss: 2.231841; val loss: 2.199577
# (Epoch 11 / 20) train loss: 2.218768; val loss: 2.183075
# (Epoch 12 / 20) train loss: 2.206333; val loss: 2.167209
# (Epoch 13 / 20) train loss: 2.194803; val loss: 2.152581
# (Epoch 14 / 20) train loss: 2.183054; val loss: 2.139775
# (Epoch 15 / 20) train loss: 2.172990; val loss: 2.127494
# (Epoch 16 / 20) train loss: 2.162415; val loss: 2.116857
# (Epoch 17 / 20) train loss: 2.153115; val loss: 2.106764
# (Epoch 18 / 20) train loss: 2.143806; val loss: 2.097798
# (Epoch 19 / 20) train loss: 2.135473; val loss: 2.089174
# (Epoch 20 / 20) train loss: 2.128558; val loss: 2.081702
#
# Evaluating Config #5 [of 30]:
#  {'learning_rate': 0.00015007214471487323, 'reg': 1.4310708343030464e-07, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed55f940>}
# (Epoch 1 / 20) train loss: 2.302607; val loss: 2.302546
# (Epoch 2 / 20) train loss: 2.296057; val loss: 2.271533
# (Epoch 3 / 20) train loss: 2.249194; val loss: 2.181482
# (Epoch 4 / 20) train loss: 2.181883; val loss: 2.105868
# (Epoch 5 / 20) train loss: 2.125701; val loss: 2.060821
# (Epoch 6 / 20) train loss: 2.084305; val loss: 2.029258
# (Epoch 7 / 20) train loss: 2.053310; val loss: 2.004465
# (Epoch 8 / 20) train loss: 2.027769; val loss: 1.979790
# (Epoch 9 / 20) train loss: 2.003409; val loss: 1.956757
# (Epoch 10 / 20) train loss: 1.982112; val loss: 1.936976
# (Epoch 11 / 20) train loss: 1.962478; val loss: 1.915083
# (Epoch 12 / 20) train loss: 1.944905; val loss: 1.903703
# (Epoch 13 / 20) train loss: 1.926583; val loss: 1.885565
# (Epoch 14 / 20) train loss: 1.907750; val loss: 1.875529
# (Epoch 15 / 20) train loss: 1.893011; val loss: 1.859076
# (Epoch 16 / 20) train loss: 1.878204; val loss: 1.844089
# (Epoch 17 / 20) train loss: 1.864198; val loss: 1.830476
# (Epoch 18 / 20) train loss: 1.851299; val loss: 1.823328
# (Epoch 19 / 20) train loss: 1.837870; val loss: 1.811180
# (Epoch 20 / 20) train loss: 1.825192; val loss: 1.803796
#
# Evaluating Config #6 [of 30]:
#  {'learning_rate': 0.00038791477891755594, 'reg': 0.0001334880263209469, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed55f940>}
# (Epoch 1 / 20) train loss: 2.302621; val loss: 2.302075
# (Epoch 2 / 20) train loss: 2.269150; val loss: 2.164743
# (Epoch 3 / 20) train loss: 2.134778; val loss: 2.032451
# (Epoch 4 / 20) train loss: 2.040523; val loss: 1.964920
# (Epoch 5 / 20) train loss: 1.981952; val loss: 1.919905
# (Epoch 6 / 20) train loss: 1.931968; val loss: 1.870953
# (Epoch 7 / 20) train loss: 1.891440; val loss: 1.839727
# (Epoch 8 / 20) train loss: 1.855924; val loss: 1.805215
# (Epoch 9 / 20) train loss: 1.826668; val loss: 1.786981
# (Epoch 10 / 20) train loss: 1.799256; val loss: 1.776654
# (Epoch 11 / 20) train loss: 1.778932; val loss: 1.764273
# (Epoch 12 / 20) train loss: 1.756582; val loss: 1.757357
# (Epoch 13 / 20) train loss: 1.739742; val loss: 1.747709
# (Epoch 14 / 20) train loss: 1.721233; val loss: 1.747892
# (Epoch 15 / 20) train loss: 1.706286; val loss: 1.729462
# (Epoch 16 / 20) train loss: 1.692990; val loss: 1.730451
# (Epoch 17 / 20) train loss: 1.677279; val loss: 1.721469
# (Epoch 18 / 20) train loss: 1.666700; val loss: 1.708161
# (Epoch 19 / 20) train loss: 1.656275; val loss: 1.706334
# (Epoch 20 / 20) train loss: 1.645278; val loss: 1.699985
#
# Evaluating Config #7 [of 30]:
#  {'learning_rate': 0.0001538793419569999, 'reg': 7.839571292640995e-08, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed55f940>}
# (Epoch 1 / 20) train loss: 2.302600; val loss: 2.302522
# (Epoch 2 / 20) train loss: 2.294720; val loss: 2.266289
# (Epoch 3 / 20) train loss: 2.244136; val loss: 2.175584
# (Epoch 4 / 20) train loss: 2.176162; val loss: 2.101528
# (Epoch 5 / 20) train loss: 2.121036; val loss: 2.058694
# (Epoch 6 / 20) train loss: 2.082017; val loss: 2.027473
# (Epoch 7 / 20) train loss: 2.052898; val loss: 2.004894
# (Epoch 8 / 20) train loss: 2.027575; val loss: 1.979618
# (Epoch 9 / 20) train loss: 2.002666; val loss: 1.955730
# (Epoch 10 / 20) train loss: 1.980061; val loss: 1.934141
# (Epoch 11 / 20) train loss: 1.959287; val loss: 1.913582
# (Epoch 12 / 20) train loss: 1.937230; val loss: 1.894824
# (Epoch 13 / 20) train loss: 1.918574; val loss: 1.877427
# (Epoch 14 / 20) train loss: 1.902511; val loss: 1.863146
# (Epoch 15 / 20) train loss: 1.883913; val loss: 1.845514
# (Epoch 16 / 20) train loss: 1.868994; val loss: 1.833151
# (Epoch 17 / 20) train loss: 1.854963; val loss: 1.821899
# (Epoch 18 / 20) train loss: 1.840356; val loss: 1.818024
# (Epoch 19 / 20) train loss: 1.828411; val loss: 1.806626
# (Epoch 20 / 20) train loss: 1.817665; val loss: 1.802282
#
# Evaluating Config #8 [of 30]:
#  {'learning_rate': 0.00024257923180039746, 'reg': 8.513139611382644e-07, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed55f940>}
# (Epoch 1 / 20) train loss: 2.302612; val loss: 2.303256
# (Epoch 2 / 20) train loss: 2.288792; val loss: 2.237079
# (Epoch 3 / 20) train loss: 2.202420; val loss: 2.103349
# (Epoch 4 / 20) train loss: 2.110280; val loss: 2.038557
# (Epoch 5 / 20) train loss: 2.053707; val loss: 1.998917
# (Epoch 6 / 20) train loss: 2.013463; val loss: 1.961021
# (Epoch 7 / 20) train loss: 1.977182; val loss: 1.930944
# (Epoch 8 / 20) train loss: 1.946498; val loss: 1.897620
# (Epoch 9 / 20) train loss: 1.919629; val loss: 1.868798
# (Epoch 10 / 20) train loss: 1.893620; val loss: 1.849776
# (Epoch 11 / 20) train loss: 1.869634; val loss: 1.831877
# (Epoch 12 / 20) train loss: 1.848841; val loss: 1.815050
# (Epoch 13 / 20) train loss: 1.829460; val loss: 1.796984
# (Epoch 14 / 20) train loss: 1.812012; val loss: 1.786093
# (Epoch 15 / 20) train loss: 1.796677; val loss: 1.776904
# (Epoch 16 / 20) train loss: 1.779064; val loss: 1.775781
# (Epoch 17 / 20) train loss: 1.765722; val loss: 1.763657
# (Epoch 18 / 20) train loss: 1.752558; val loss: 1.751059
# (Epoch 19 / 20) train loss: 1.740840; val loss: 1.752824
# (Epoch 20 / 20) train loss: 1.727387; val loss: 1.745693
#
# Evaluating Config #9 [of 30]:
#  {'learning_rate': 0.005993568845680735, 'reg': 3.142006911911286e-05, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed55f940>}
# (Epoch 1 / 20) train loss: 2.302656; val loss: 2.303059
# (Epoch 2 / 20) train loss: 2.058976; val loss: 1.858241
# (Epoch 3 / 20) train loss: 1.830275; val loss: 1.724022
# (Epoch 4 / 20) train loss: 1.738771; val loss: 1.731948
# (Epoch 5 / 20) train loss: 1.683084; val loss: 1.673143
# (Epoch 6 / 20) train loss: 1.648691; val loss: 1.712089
# (Epoch 7 / 20) train loss: 1.625640; val loss: 1.689512
# (Epoch 8 / 20) train loss: 1.607117; val loss: 1.644532
# (Epoch 9 / 20) train loss: 1.583795; val loss: 1.709828
# (Epoch 10 / 20) train loss: 1.558471; val loss: 1.613084
# (Epoch 11 / 20) train loss: 1.544714; val loss: 1.597203
# (Epoch 12 / 20) train loss: 1.531925; val loss: 1.637385
# (Epoch 13 / 20) train loss: 1.519073; val loss: 1.573042
# (Epoch 14 / 20) train loss: 1.504356; val loss: 1.601602
# (Epoch 15 / 20) train loss: 1.487145; val loss: 1.693758
# (Epoch 16 / 20) train loss: 1.473052; val loss: 1.651256
# (Epoch 17 / 20) train loss: 1.459404; val loss: 1.703481
# (Epoch 18 / 20) train loss: 1.460488; val loss: 1.711620
# Stopping early at epoch 17!
#
# Evaluating Config #10 [of 30]:
#  {'learning_rate': 2.27293193082617e-05, 'reg': 5.424785438956909e-05, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed55f940>}
# (Epoch 1 / 20) train loss: 2.302591; val loss: 2.302599
# (Epoch 2 / 20) train loss: 2.302337; val loss: 2.301523
# (Epoch 3 / 20) train loss: 2.301393; val loss: 2.299447
# (Epoch 4 / 20) train loss: 2.299231; val loss: 2.295465
# (Epoch 5 / 20) train loss: 2.294892; val loss: 2.287818
# (Epoch 6 / 20) train loss: 2.287641; val loss: 2.276774
# (Epoch 7 / 20) train loss: 2.277826; val loss: 2.262636
# (Epoch 8 / 20) train loss: 2.266791; val loss: 2.246476
# (Epoch 9 / 20) train loss: 2.254471; val loss: 2.229855
# (Epoch 10 / 20) train loss: 2.242002; val loss: 2.213106
# (Epoch 11 / 20) train loss: 2.229775; val loss: 2.196647
# (Epoch 12 / 20) train loss: 2.216986; val loss: 2.180801
# (Epoch 13 / 20) train loss: 2.205499; val loss: 2.165800
# (Epoch 14 / 20) train loss: 2.194031; val loss: 2.152101
# (Epoch 15 / 20) train loss: 2.183263; val loss: 2.139545
# (Epoch 16 / 20) train loss: 2.173037; val loss: 2.128024
# (Epoch 17 / 20) train loss: 2.163252; val loss: 2.117659
# (Epoch 18 / 20) train loss: 2.155028; val loss: 2.108318
# (Epoch 19 / 20) train loss: 2.145450; val loss: 2.099583
# (Epoch 20 / 20) train loss: 2.138152; val loss: 2.091350
#
# Evaluating Config #11 [of 30]:
#  {'learning_rate': 4.07479314892627e-05, 'reg': 0.0005858059099117488, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed55f940>}
# (Epoch 1 / 20) train loss: 2.302776; val loss: 2.302927
# (Epoch 2 / 20) train loss: 2.302200; val loss: 2.300093
# (Epoch 3 / 20) train loss: 2.298901; val loss: 2.292856
# (Epoch 4 / 20) train loss: 2.289639; val loss: 2.276133
# (Epoch 5 / 20) train loss: 2.273375; val loss: 2.251093
# (Epoch 6 / 20) train loss: 2.253158; val loss: 2.222228
# (Epoch 7 / 20) train loss: 2.231126; val loss: 2.193460
# (Epoch 8 / 20) train loss: 2.210656; val loss: 2.165814
# (Epoch 9 / 20) train loss: 2.190139; val loss: 2.142459
# (Epoch 10 / 20) train loss: 2.171923; val loss: 2.122394
# (Epoch 11 / 20) train loss: 2.155118; val loss: 2.105537
# (Epoch 12 / 20) train loss: 2.139445; val loss: 2.090197
# (Epoch 13 / 20) train loss: 2.126105; val loss: 2.077628
# (Epoch 14 / 20) train loss: 2.114881; val loss: 2.065756
# (Epoch 15 / 20) train loss: 2.103526; val loss: 2.055027
# (Epoch 16 / 20) train loss: 2.093767; val loss: 2.045880
# (Epoch 17 / 20) train loss: 2.084601; val loss: 2.037631
# (Epoch 18 / 20) train loss: 2.076136; val loss: 2.029806
# (Epoch 19 / 20) train loss: 2.068774; val loss: 2.021828
# (Epoch 20 / 20) train loss: 2.060619; val loss: 2.015442
#
# Evaluating Config #12 [of 30]:
#  {'learning_rate': 6.367908216849981e-05, 'reg': 0.009775094278815231, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed55f940>}
# (Epoch 1 / 20) train loss: 2.305601; val loss: 2.306058
# (Epoch 2 / 20) train loss: 2.303894; val loss: 2.299432
# (Epoch 3 / 20) train loss: 2.295449; val loss: 2.281367
# (Epoch 4 / 20) train loss: 2.275048; val loss: 2.246035
# (Epoch 5 / 20) train loss: 2.247100; val loss: 2.206237
# (Epoch 6 / 20) train loss: 2.219478; val loss: 2.172036
# (Epoch 7 / 20) train loss: 2.195985; val loss: 2.145831
# (Epoch 8 / 20) train loss: 2.175425; val loss: 2.124794
# (Epoch 9 / 20) train loss: 2.159245; val loss: 2.108381
# (Epoch 10 / 20) train loss: 2.146318; val loss: 2.093986
# (Epoch 11 / 20) train loss: 2.135721; val loss: 2.083529
# (Epoch 12 / 20) train loss: 2.124787; val loss: 2.073837
# (Epoch 13 / 20) train loss: 2.116627; val loss: 2.064618
# (Epoch 14 / 20) train loss: 2.108670; val loss: 2.056624
# (Epoch 15 / 20) train loss: 2.102323; val loss: 2.049121
# (Epoch 16 / 20) train loss: 2.094251; val loss: 2.043153
# (Epoch 17 / 20) train loss: 2.086899; val loss: 2.035629
# (Epoch 18 / 20) train loss: 2.081088; val loss: 2.029755
# (Epoch 19 / 20) train loss: 2.074422; val loss: 2.024295
# (Epoch 20 / 20) train loss: 2.068084; val loss: 2.019262
#
# Evaluating Config #13 [of 30]:
#  {'learning_rate': 0.0015682891413644794, 'reg': 3.3523920307973294e-06, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed55f940>}
# (Epoch 1 / 20) train loss: 2.302595; val loss: 2.302984
# (Epoch 2 / 20) train loss: 2.142038; val loss: 1.958059
# (Epoch 3 / 20) train loss: 1.918855; val loss: 1.807000
# (Epoch 4 / 20) train loss: 1.816466; val loss: 1.761897
# (Epoch 5 / 20) train loss: 1.744666; val loss: 1.737339
# (Epoch 6 / 20) train loss: 1.693361; val loss: 1.677102
# (Epoch 7 / 20) train loss: 1.655520; val loss: 1.692967
# (Epoch 8 / 20) train loss: 1.618940; val loss: 1.659172
# (Epoch 9 / 20) train loss: 1.591323; val loss: 1.633786
# (Epoch 10 / 20) train loss: 1.561849; val loss: 1.602708
# (Epoch 11 / 20) train loss: 1.534564; val loss: 1.596336
# (Epoch 12 / 20) train loss: 1.510982; val loss: 1.568469
# (Epoch 13 / 20) train loss: 1.492958; val loss: 1.565206
# (Epoch 14 / 20) train loss: 1.470996; val loss: 1.578944
# (Epoch 15 / 20) train loss: 1.444691; val loss: 1.564351
# (Epoch 16 / 20) train loss: 1.424820; val loss: 1.550504
# (Epoch 17 / 20) train loss: 1.409527; val loss: 1.596378
# (Epoch 18 / 20) train loss: 1.386402; val loss: 1.568266
# (Epoch 19 / 20) train loss: 1.367894; val loss: 1.513468
# (Epoch 20 / 20) train loss: 1.348782; val loss: 1.521657
#
# Evaluating Config #14 [of 30]:
#  {'learning_rate': 0.00016936272950000646, 'reg': 7.482207111264584e-06, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed55f940>}
# (Epoch 1 / 20) train loss: 2.302629; val loss: 2.303124
# (Epoch 2 / 20) train loss: 2.295209; val loss: 2.266322
# (Epoch 3 / 20) train loss: 2.238979; val loss: 2.162492
# (Epoch 4 / 20) train loss: 2.161525; val loss: 2.083109
# (Epoch 5 / 20) train loss: 2.101733; val loss: 2.038808
# (Epoch 6 / 20) train loss: 2.060835; val loss: 2.005460
# (Epoch 7 / 20) train loss: 2.029843; val loss: 1.974708
# (Epoch 8 / 20) train loss: 2.003544; val loss: 1.951185
# (Epoch 9 / 20) train loss: 1.978823; val loss: 1.926865
# (Epoch 10 / 20) train loss: 1.956418; val loss: 1.904748
# (Epoch 11 / 20) train loss: 1.934621; val loss: 1.888988
# (Epoch 12 / 20) train loss: 1.915193; val loss: 1.863426
# (Epoch 13 / 20) train loss: 1.896079; val loss: 1.853391
# (Epoch 14 / 20) train loss: 1.879906; val loss: 1.842946
# (Epoch 15 / 20) train loss: 1.863069; val loss: 1.828220
# (Epoch 16 / 20) train loss: 1.847921; val loss: 1.812473
# (Epoch 17 / 20) train loss: 1.833853; val loss: 1.808809
# (Epoch 18 / 20) train loss: 1.819709; val loss: 1.793940
# (Epoch 19 / 20) train loss: 1.807227; val loss: 1.790574
# (Epoch 20 / 20) train loss: 1.798873; val loss: 1.784283
#
# Evaluating Config #15 [of 30]:
#  {'learning_rate': 2.9010478569117388e-05, 'reg': 1.6884296875731565e-06, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed55f940>}
# (Epoch 1 / 20) train loss: 2.302616; val loss: 2.303089
# (Epoch 2 / 20) train loss: 2.302281; val loss: 2.301285
# (Epoch 3 / 20) train loss: 2.300818; val loss: 2.297889
# (Epoch 4 / 20) train loss: 2.296914; val loss: 2.290599
# (Epoch 5 / 20) train loss: 2.288565; val loss: 2.276922
# (Epoch 6 / 20) train loss: 2.276018; val loss: 2.257598
# (Epoch 7 / 20) train loss: 2.260452; val loss: 2.236726
# (Epoch 8 / 20) train loss: 2.244308; val loss: 2.214449
# (Epoch 9 / 20) train loss: 2.228110; val loss: 2.193121
# (Epoch 10 / 20) train loss: 2.212620; val loss: 2.173088
# (Epoch 11 / 20) train loss: 2.197479; val loss: 2.154915
# (Epoch 12 / 20) train loss: 2.183112; val loss: 2.138694
# (Epoch 13 / 20) train loss: 2.170312; val loss: 2.124277
# (Epoch 14 / 20) train loss: 2.157595; val loss: 2.111463
# (Epoch 15 / 20) train loss: 2.147102; val loss: 2.099199
# (Epoch 16 / 20) train loss: 2.135404; val loss: 2.089547
# (Epoch 17 / 20) train loss: 2.126075; val loss: 2.080019
# (Epoch 18 / 20) train loss: 2.116778; val loss: 2.071551
# (Epoch 19 / 20) train loss: 2.109704; val loss: 2.063852
# (Epoch 20 / 20) train loss: 2.101905; val loss: 2.056648
#
# Evaluating Config #16 [of 30]:
#  {'learning_rate': 0.002367077352352542, 'reg': 7.19728105691815e-05, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed55f940>}
# (Epoch 1 / 20) train loss: 2.302625; val loss: 2.302633
# (Epoch 2 / 20) train loss: 2.095652; val loss: 1.905703
# (Epoch 3 / 20) train loss: 1.854646; val loss: 1.761942
# (Epoch 4 / 20) train loss: 1.754474; val loss: 1.735011
# (Epoch 5 / 20) train loss: 1.690459; val loss: 1.726958
# (Epoch 6 / 20) train loss: 1.653467; val loss: 1.690542
# (Epoch 7 / 20) train loss: 1.617535; val loss: 1.659350
# (Epoch 8 / 20) train loss: 1.584949; val loss: 1.652255
# (Epoch 9 / 20) train loss: 1.567083; val loss: 1.669219
# (Epoch 10 / 20) train loss: 1.536417; val loss: 1.631050
# (Epoch 11 / 20) train loss: 1.516001; val loss: 1.658190
# (Epoch 12 / 20) train loss: 1.492360; val loss: 1.661482
# (Epoch 13 / 20) train loss: 1.472505; val loss: 1.628999
# (Epoch 14 / 20) train loss: 1.447063; val loss: 1.648065
# (Epoch 15 / 20) train loss: 1.431909; val loss: 1.638979
# (Epoch 16 / 20) train loss: 1.413517; val loss: 1.585834
# (Epoch 17 / 20) train loss: 1.390478; val loss: 1.584806
# (Epoch 18 / 20) train loss: 1.371859; val loss: 1.574123
# (Epoch 19 / 20) train loss: 1.354158; val loss: 1.582811
# (Epoch 20 / 20) train loss: 1.341092; val loss: 1.578820
#
# Evaluating Config #17 [of 30]:
#  {'learning_rate': 0.0003142620477719451, 'reg': 2.0119928138149133e-08, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed55f940>}
# (Epoch 1 / 20) train loss: 2.302589; val loss: 2.302192
# (Epoch 2 / 20) train loss: 2.279507; val loss: 2.204916
# (Epoch 3 / 20) train loss: 2.169035; val loss: 2.063000
# (Epoch 4 / 20) train loss: 2.071013; val loss: 1.998344
# (Epoch 5 / 20) train loss: 2.012931; val loss: 1.952844
# (Epoch 6 / 20) train loss: 1.967626; val loss: 1.911721
# (Epoch 7 / 20) train loss: 1.928000; val loss: 1.872981
# (Epoch 8 / 20) train loss: 1.896594; val loss: 1.850823
# (Epoch 9 / 20) train loss: 1.865921; val loss: 1.829145
# (Epoch 10 / 20) train loss: 1.837842; val loss: 1.797557
# (Epoch 11 / 20) train loss: 1.815319; val loss: 1.789033
# (Epoch 12 / 20) train loss: 1.796743; val loss: 1.768196
# (Epoch 13 / 20) train loss: 1.774533; val loss: 1.765249
# (Epoch 14 / 20) train loss: 1.758182; val loss: 1.754642
# (Epoch 15 / 20) train loss: 1.742332; val loss: 1.743029
# (Epoch 16 / 20) train loss: 1.726546; val loss: 1.732049
# (Epoch 17 / 20) train loss: 1.713492; val loss: 1.721480
# (Epoch 18 / 20) train loss: 1.698721; val loss: 1.714468
# (Epoch 19 / 20) train loss: 1.688284; val loss: 1.702302
# (Epoch 20 / 20) train loss: 1.677037; val loss: 1.700556
#
# Evaluating Config #18 [of 30]:
#  {'learning_rate': 1.1157843922332466e-05, 'reg': 7.439076347633988e-08, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed55f940>}
# (Epoch 1 / 20) train loss: 2.302628; val loss: 2.303035
# (Epoch 2 / 20) train loss: 2.302461; val loss: 2.302092
# (Epoch 3 / 20) train loss: 2.302056; val loss: 2.301344
# (Epoch 4 / 20) train loss: 2.301482; val loss: 2.300208
# (Epoch 5 / 20) train loss: 2.300617; val loss: 2.298738
# (Epoch 6 / 20) train loss: 2.299301; val loss: 2.296627
# (Epoch 7 / 20) train loss: 2.297294; val loss: 2.293668
# (Epoch 8 / 20) train loss: 2.294673; val loss: 2.289602
# (Epoch 9 / 20) train loss: 2.291125; val loss: 2.284657
# (Epoch 10 / 20) train loss: 2.286853; val loss: 2.278729
# (Epoch 11 / 20) train loss: 2.281886; val loss: 2.271819
# (Epoch 12 / 20) train loss: 2.276380; val loss: 2.264256
# (Epoch 13 / 20) train loss: 2.270473; val loss: 2.256302
# (Epoch 14 / 20) train loss: 2.264335; val loss: 2.248066
# (Epoch 15 / 20) train loss: 2.258175; val loss: 2.239790
# (Epoch 16 / 20) train loss: 2.251987; val loss: 2.231365
# (Epoch 17 / 20) train loss: 2.245592; val loss: 2.223015
# (Epoch 18 / 20) train loss: 2.239617; val loss: 2.214753
# (Epoch 19 / 20) train loss: 2.233695; val loss: 2.206519
# (Epoch 20 / 20) train loss: 2.227890; val loss: 2.198615
#
# Evaluating Config #19 [of 30]:
#  {'learning_rate': 5.234316448411929e-05, 'reg': 0.005406528410267541, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed55f940>}
# (Epoch 1 / 20) train loss: 2.304269; val loss: 2.304662
# (Epoch 2 / 20) train loss: 2.303353; val loss: 2.300634
# (Epoch 3 / 20) train loss: 2.298398; val loss: 2.289758
# (Epoch 4 / 20) train loss: 2.284763; val loss: 2.265968
# (Epoch 5 / 20) train loss: 2.262751; val loss: 2.232589
# (Epoch 6 / 20) train loss: 2.237779; val loss: 2.198671
# (Epoch 7 / 20) train loss: 2.213115; val loss: 2.168057
# (Epoch 8 / 20) train loss: 2.189825; val loss: 2.142230
# (Epoch 9 / 20) train loss: 2.170571; val loss: 2.122209
# (Epoch 10 / 20) train loss: 2.153548; val loss: 2.105817
# (Epoch 11 / 20) train loss: 2.138767; val loss: 2.090862
# (Epoch 12 / 20) train loss: 2.126265; val loss: 2.078453
# (Epoch 13 / 20) train loss: 2.115624; val loss: 2.067479
# (Epoch 14 / 20) train loss: 2.104302; val loss: 2.056645
# (Epoch 15 / 20) train loss: 2.095059; val loss: 2.047742
# (Epoch 16 / 20) train loss: 2.087131; val loss: 2.040183
# (Epoch 17 / 20) train loss: 2.079130; val loss: 2.031205
# (Epoch 18 / 20) train loss: 2.072084; val loss: 2.025130
# (Epoch 19 / 20) train loss: 2.064884; val loss: 2.018333
# (Epoch 20 / 20) train loss: 2.057806; val loss: 2.010777
#
# Evaluating Config #20 [of 30]:
#  {'learning_rate': 9.157968016989939e-05, 'reg': 1.571435918527757e-05, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed55f940>}
# (Epoch 1 / 20) train loss: 2.302587; val loss: 2.302047
# (Epoch 2 / 20) train loss: 2.300475; val loss: 2.292713
# (Epoch 3 / 20) train loss: 2.281152; val loss: 2.250030
# (Epoch 4 / 20) train loss: 2.239661; val loss: 2.187458
# (Epoch 5 / 20) train loss: 2.193784; val loss: 2.132267
# (Epoch 6 / 20) train loss: 2.153072; val loss: 2.093927
# (Epoch 7 / 20) train loss: 2.120304; val loss: 2.066264
# (Epoch 8 / 20) train loss: 2.092881; val loss: 2.043041
# (Epoch 9 / 20) train loss: 2.071906; val loss: 2.025188
# (Epoch 10 / 20) train loss: 2.053013; val loss: 2.009653
# (Epoch 11 / 20) train loss: 2.036043; val loss: 1.993271
# (Epoch 12 / 20) train loss: 2.020429; val loss: 1.979202
# (Epoch 13 / 20) train loss: 2.007085; val loss: 1.966496
# (Epoch 14 / 20) train loss: 1.993701; val loss: 1.952999
# (Epoch 15 / 20) train loss: 1.980455; val loss: 1.938767
# (Epoch 16 / 20) train loss: 1.968744; val loss: 1.926304
# (Epoch 17 / 20) train loss: 1.954168; val loss: 1.913763
# (Epoch 18 / 20) train loss: 1.943698; val loss: 1.902820
# (Epoch 19 / 20) train loss: 1.932109; val loss: 1.891185
# (Epoch 20 / 20) train loss: 1.923067; val loss: 1.882813
#
# Evaluating Config #21 [of 30]:
#  {'learning_rate': 0.005499365574650877, 'reg': 0.00034593485544287577, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed55f940>}
# (Epoch 1 / 20) train loss: 2.302675; val loss: 2.301977
# (Epoch 2 / 20) train loss: 2.036554; val loss: 1.830988
# (Epoch 3 / 20) train loss: 1.824415; val loss: 1.776741
# (Epoch 4 / 20) train loss: 1.761221; val loss: 1.774295
# (Epoch 5 / 20) train loss: 1.746155; val loss: 1.747061
# (Epoch 6 / 20) train loss: 1.727627; val loss: 1.788199
# (Epoch 7 / 20) train loss: 1.707572; val loss: 1.764693
# (Epoch 8 / 20) train loss: 1.699830; val loss: 1.748082
# (Epoch 9 / 20) train loss: 1.699470; val loss: 1.781546
# (Epoch 10 / 20) train loss: 1.700566; val loss: 1.777472
# Stopping early at epoch 9!
#
# Evaluating Config #22 [of 30]:
#  {'learning_rate': 1.5450641624133814e-05, 'reg': 1.2941267260213356e-08, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed55f940>}
# (Epoch 1 / 20) train loss: 2.302577; val loss: 2.302217
# (Epoch 2 / 20) train loss: 2.302376; val loss: 2.301480
# (Epoch 3 / 20) train loss: 2.301759; val loss: 2.300048
# (Epoch 4 / 20) train loss: 2.300704; val loss: 2.298250
# (Epoch 5 / 20) train loss: 2.298822; val loss: 2.295214
# (Epoch 6 / 20) train loss: 2.295747; val loss: 2.290563
# (Epoch 7 / 20) train loss: 2.291406; val loss: 2.283870
# (Epoch 8 / 20) train loss: 2.285590; val loss: 2.275848
# (Epoch 9 / 20) train loss: 2.278641; val loss: 2.266089
# (Epoch 10 / 20) train loss: 2.270928; val loss: 2.255469
# (Epoch 11 / 20) train loss: 2.262593; val loss: 2.244242
# (Epoch 12 / 20) train loss: 2.254429; val loss: 2.232868
# (Epoch 13 / 20) train loss: 2.245990; val loss: 2.221517
# (Epoch 14 / 20) train loss: 2.237677; val loss: 2.210319
# (Epoch 15 / 20) train loss: 2.229161; val loss: 2.199310
# (Epoch 16 / 20) train loss: 2.221151; val loss: 2.188572
# (Epoch 17 / 20) train loss: 2.213420; val loss: 2.178376
# (Epoch 18 / 20) train loss: 2.205981; val loss: 2.168714
# (Epoch 19 / 20) train loss: 2.198216; val loss: 2.159438
# (Epoch 20 / 20) train loss: 2.191353; val loss: 2.150720
#
# Evaluating Config #23 [of 30]:
#  {'learning_rate': 0.001073403356768427, 'reg': 6.009887891184065e-05, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed55f940>}
# (Epoch 1 / 20) train loss: 2.302660; val loss: 2.302913
# (Epoch 2 / 20) train loss: 2.197335; val loss: 2.021755
# (Epoch 3 / 20) train loss: 1.986814; val loss: 1.881878
# (Epoch 4 / 20) train loss: 1.876723; val loss: 1.794645
# (Epoch 5 / 20) train loss: 1.803151; val loss: 1.765481
# (Epoch 6 / 20) train loss: 1.749864; val loss: 1.730604
# (Epoch 7 / 20) train loss: 1.707491; val loss: 1.708875
# (Epoch 8 / 20) train loss: 1.675162; val loss: 1.721906
# (Epoch 9 / 20) train loss: 1.646952; val loss: 1.691888
# (Epoch 10 / 20) train loss: 1.619910; val loss: 1.693982
# (Epoch 11 / 20) train loss: 1.598487; val loss: 1.651463
# (Epoch 12 / 20) train loss: 1.579732; val loss: 1.654993
# (Epoch 13 / 20) train loss: 1.562261; val loss: 1.639060
# (Epoch 14 / 20) train loss: 1.539303; val loss: 1.639200
# (Epoch 15 / 20) train loss: 1.522981; val loss: 1.615526
# (Epoch 16 / 20) train loss: 1.510321; val loss: 1.630089
# (Epoch 17 / 20) train loss: 1.496778; val loss: 1.612017
# (Epoch 18 / 20) train loss: 1.479180; val loss: 1.632725
# (Epoch 19 / 20) train loss: 1.466929; val loss: 1.603880
# (Epoch 20 / 20) train loss: 1.448417; val loss: 1.629429
#
# Evaluating Config #24 [of 30]:
#  {'learning_rate': 0.00043750989396728555, 'reg': 5.628587479267723e-07, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed55f940>}
# (Epoch 1 / 20) train loss: 2.302610; val loss: 2.302803
# (Epoch 2 / 20) train loss: 2.265423; val loss: 2.155816
# (Epoch 3 / 20) train loss: 2.134770; val loss: 2.039301
# (Epoch 4 / 20) train loss: 2.040136; val loss: 1.977589
# (Epoch 5 / 20) train loss: 1.974310; val loss: 1.912813
# (Epoch 6 / 20) train loss: 1.918985; val loss: 1.862455
# (Epoch 7 / 20) train loss: 1.873583; val loss: 1.821433
# (Epoch 8 / 20) train loss: 1.835925; val loss: 1.798583
# (Epoch 9 / 20) train loss: 1.805085; val loss: 1.773765
# (Epoch 10 / 20) train loss: 1.778751; val loss: 1.763706
# (Epoch 11 / 20) train loss: 1.754669; val loss: 1.753495
# (Epoch 12 / 20) train loss: 1.734268; val loss: 1.743183
# (Epoch 13 / 20) train loss: 1.711336; val loss: 1.725254
# (Epoch 14 / 20) train loss: 1.695069; val loss: 1.725042
# (Epoch 15 / 20) train loss: 1.677123; val loss: 1.709121
# (Epoch 16 / 20) train loss: 1.663571; val loss: 1.703006
# (Epoch 17 / 20) train loss: 1.647187; val loss: 1.696747
# (Epoch 18 / 20) train loss: 1.637480; val loss: 1.688218
# (Epoch 19 / 20) train loss: 1.621925; val loss: 1.667417
# (Epoch 20 / 20) train loss: 1.609438; val loss: 1.669235
#
# Evaluating Config #25 [of 30]:
#  {'learning_rate': 0.0002354684079779243, 'reg': 1.0970651009689527e-08, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed55f940>}
# (Epoch 1 / 20) train loss: 2.302613; val loss: 2.302970
# (Epoch 2 / 20) train loss: 2.287515; val loss: 2.237097
# (Epoch 3 / 20) train loss: 2.202135; val loss: 2.104998
# (Epoch 4 / 20) train loss: 2.111287; val loss: 2.039671
# (Epoch 5 / 20) train loss: 2.054551; val loss: 2.001490
# (Epoch 6 / 20) train loss: 2.015159; val loss: 1.960482
# (Epoch 7 / 20) train loss: 1.978645; val loss: 1.921858
# (Epoch 8 / 20) train loss: 1.948141; val loss: 1.895996
# (Epoch 9 / 20) train loss: 1.919890; val loss: 1.872223
# (Epoch 10 / 20) train loss: 1.893879; val loss: 1.842477
# (Epoch 11 / 20) train loss: 1.871419; val loss: 1.837000
# (Epoch 12 / 20) train loss: 1.849740; val loss: 1.814665
# (Epoch 13 / 20) train loss: 1.829934; val loss: 1.804459
# (Epoch 14 / 20) train loss: 1.813427; val loss: 1.797649
# (Epoch 15 / 20) train loss: 1.795704; val loss: 1.784299
# (Epoch 16 / 20) train loss: 1.780358; val loss: 1.780401
# (Epoch 17 / 20) train loss: 1.766951; val loss: 1.770201
# (Epoch 18 / 20) train loss: 1.754894; val loss: 1.761246
# (Epoch 19 / 20) train loss: 1.741655; val loss: 1.755704
# (Epoch 20 / 20) train loss: 1.732206; val loss: 1.744507
#
# Evaluating Config #26 [of 30]:
#  {'learning_rate': 0.0007611204076885661, 'reg': 1.0814051682822901e-07, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed55f940>}
# (Epoch 1 / 20) train loss: 2.302610; val loss: 2.302599
# (Epoch 2 / 20) train loss: 2.219426; val loss: 2.058972
# (Epoch 3 / 20) train loss: 2.037287; val loss: 1.941034
# (Epoch 4 / 20) train loss: 1.935116; val loss: 1.864575
# (Epoch 5 / 20) train loss: 1.863781; val loss: 1.803178
# (Epoch 6 / 20) train loss: 1.806892; val loss: 1.780672
# (Epoch 7 / 20) train loss: 1.766604; val loss: 1.757837
# (Epoch 8 / 20) train loss: 1.729647; val loss: 1.735662
# (Epoch 9 / 20) train loss: 1.698420; val loss: 1.714294
# (Epoch 10 / 20) train loss: 1.674083; val loss: 1.709091
# (Epoch 11 / 20) train loss: 1.649085; val loss: 1.686675
# (Epoch 12 / 20) train loss: 1.627241; val loss: 1.677402
# (Epoch 13 / 20) train loss: 1.610273; val loss: 1.697563
# (Epoch 14 / 20) train loss: 1.593040; val loss: 1.666049
# (Epoch 15 / 20) train loss: 1.574466; val loss: 1.698311
# (Epoch 16 / 20) train loss: 1.561527; val loss: 1.649323
# (Epoch 17 / 20) train loss: 1.545043; val loss: 1.657857
# (Epoch 18 / 20) train loss: 1.529254; val loss: 1.651596
# (Epoch 19 / 20) train loss: 1.519989; val loss: 1.675577
# (Epoch 20 / 20) train loss: 1.504167; val loss: 1.652625
#
# Evaluating Config #27 [of 30]:
#  {'learning_rate': 0.0001388532860172581, 'reg': 1.7267670272649455e-05, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed55f940>}
# (Epoch 1 / 20) train loss: 2.302649; val loss: 2.302667
# (Epoch 2 / 20) train loss: 2.296638; val loss: 2.276097
# (Epoch 3 / 20) train loss: 2.253295; val loss: 2.190563
# (Epoch 4 / 20) train loss: 2.188157; val loss: 2.113724
# (Epoch 5 / 20) train loss: 2.133986; val loss: 2.068376
# (Epoch 6 / 20) train loss: 2.094789; val loss: 2.036415
# (Epoch 7 / 20) train loss: 2.065938; val loss: 2.011912
# (Epoch 8 / 20) train loss: 2.041144; val loss: 1.989685
# (Epoch 9 / 20) train loss: 2.019085; val loss: 1.971330
# (Epoch 10 / 20) train loss: 1.998889; val loss: 1.949831
# (Epoch 11 / 20) train loss: 1.977727; val loss: 1.933059
# (Epoch 12 / 20) train loss: 1.959895; val loss: 1.917757
# (Epoch 13 / 20) train loss: 1.940457; val loss: 1.897780
# (Epoch 14 / 20) train loss: 1.924391; val loss: 1.882777
# (Epoch 15 / 20) train loss: 1.908987; val loss: 1.867783
# (Epoch 16 / 20) train loss: 1.892557; val loss: 1.856186
# (Epoch 17 / 20) train loss: 1.878339; val loss: 1.840538
# (Epoch 18 / 20) train loss: 1.865172; val loss: 1.833792
# (Epoch 19 / 20) train loss: 1.852911; val loss: 1.820375
# (Epoch 20 / 20) train loss: 1.840878; val loss: 1.810746
#
# Evaluating Config #28 [of 30]:
#  {'learning_rate': 0.004820157557871424, 'reg': 9.671674328500637e-07, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed55f940>}
# (Epoch 1 / 20) train loss: 2.302623; val loss: 2.303124
# (Epoch 2 / 20) train loss: 2.024848; val loss: 1.796251
# (Epoch 3 / 20) train loss: 1.798669; val loss: 1.722349
# (Epoch 4 / 20) train loss: 1.704068; val loss: 1.637841
# (Epoch 5 / 20) train loss: 1.654678; val loss: 1.663779
# (Epoch 6 / 20) train loss: 1.616816; val loss: 1.643727
# (Epoch 7 / 20) train loss: 1.582193; val loss: 1.641031
# (Epoch 8 / 20) train loss: 1.550962; val loss: 1.616591
# (Epoch 9 / 20) train loss: 1.521669; val loss: 1.693879
# (Epoch 10 / 20) train loss: 1.496942; val loss: 1.638035
# (Epoch 11 / 20) train loss: 1.472532; val loss: 1.612788
# (Epoch 12 / 20) train loss: 1.447345; val loss: 1.604294
# (Epoch 13 / 20) train loss: 1.426356; val loss: 1.636274
# (Epoch 14 / 20) train loss: 1.400048; val loss: 1.549039
# (Epoch 15 / 20) train loss: 1.386686; val loss: 1.587086
# (Epoch 16 / 20) train loss: 1.360216; val loss: 1.582215
# (Epoch 17 / 20) train loss: 1.342893; val loss: 1.674965
# (Epoch 18 / 20) train loss: 1.323695; val loss: 1.605073
# (Epoch 19 / 20) train loss: 1.299643; val loss: 1.622039
# Stopping early at epoch 18!
#
# Evaluating Config #29 [of 30]:
#  {'learning_rate': 2.4280706097856252e-05, 'reg': 1.8684307986244883e-06, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed55f940>}
# (Epoch 1 / 20) train loss: 2.302607; val loss: 2.302051
# (Epoch 2 / 20) train loss: 2.302330; val loss: 2.300743
# (Epoch 3 / 20) train loss: 2.301250; val loss: 2.298476
# (Epoch 4 / 20) train loss: 2.298807; val loss: 2.293886
# (Epoch 5 / 20) train loss: 2.293921; val loss: 2.285472
# (Epoch 6 / 20) train loss: 2.285895; val loss: 2.273320
# (Epoch 7 / 20) train loss: 2.275232; val loss: 2.258163
# (Epoch 8 / 20) train loss: 2.262945; val loss: 2.240963
# (Epoch 9 / 20) train loss: 2.250388; val loss: 2.223297
# (Epoch 10 / 20) train loss: 2.236960; val loss: 2.205720
# (Epoch 11 / 20) train loss: 2.223789; val loss: 2.188726
# (Epoch 12 / 20) train loss: 2.210837; val loss: 2.172554
# (Epoch 13 / 20) train loss: 2.199393; val loss: 2.157340
# (Epoch 14 / 20) train loss: 2.187456; val loss: 2.143643
# (Epoch 15 / 20) train loss: 2.175911; val loss: 2.131243
# (Epoch 16 / 20) train loss: 2.165074; val loss: 2.119467
# (Epoch 17 / 20) train loss: 2.155297; val loss: 2.109197
# (Epoch 18 / 20) train loss: 2.145723; val loss: 2.099558
# (Epoch 19 / 20) train loss: 2.136831; val loss: 2.090848
# (Epoch 20 / 20) train loss: 2.128373; val loss: 2.082838
#
# Evaluating Config #30 [of 30]:
#  {'learning_rate': 0.0019355390611408728, 'reg': 4.119060062756502e-08, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed55f940>}
# (Epoch 1 / 20) train loss: 2.302609; val loss: 2.302708
# (Epoch 2 / 20) train loss: 2.122007; val loss: 1.933615
# (Epoch 3 / 20) train loss: 1.890668; val loss: 1.770244
# (Epoch 4 / 20) train loss: 1.782878; val loss: 1.739911
# (Epoch 5 / 20) train loss: 1.712514; val loss: 1.734681
# (Epoch 6 / 20) train loss: 1.664145; val loss: 1.684044
# (Epoch 7 / 20) train loss: 1.624130; val loss: 1.668435
# (Epoch 8 / 20) train loss: 1.593796; val loss: 1.653338
# (Epoch 9 / 20) train loss: 1.559535; val loss: 1.640095
# (Epoch 10 / 20) train loss: 1.533058; val loss: 1.605020
# (Epoch 11 / 20) train loss: 1.509252; val loss: 1.626876
# (Epoch 12 / 20) train loss: 1.485898; val loss: 1.595418
# (Epoch 13 / 20) train loss: 1.462975; val loss: 1.613854
# (Epoch 14 / 20) train loss: 1.440575; val loss: 1.571441
# (Epoch 15 / 20) train loss: 1.417945; val loss: 1.586587
# (Epoch 16 / 20) train loss: 1.401091; val loss: 1.590133
# (Epoch 17 / 20) train loss: 1.382380; val loss: 1.605779
# (Epoch 18 / 20) train loss: 1.353734; val loss: 1.582797
# (Epoch 19 / 20) train loss: 1.334884; val loss: 1.590596
# Stopping early at epoch 18!
#
# Search done. Best Val Loss = 1.513468112630078
# Best Config: {'learning_rate': 0.0015682891413644794, 'reg': 3.3523920307973294e-06, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x7f76ed55f940>}
#
#
#
# (Epoch 1 / 100) train loss: 2.297826; val loss: 2.604023
# (Epoch 2 / 100) train loss: 2.127364; val loss: 2.062227
# (Epoch 3 / 100) train loss: 1.811890; val loss: 1.902291
# (Epoch 4 / 100) train loss: 1.746744; val loss: 1.869895
# (Epoch 5 / 100) train loss: 1.746636; val loss: 1.856869
# (Epoch 6 / 100) train loss: 1.738485; val loss: 1.850856
# (Epoch 7 / 100) train loss: 1.730253; val loss: 1.825993
# (Epoch 8 / 100) train loss: 1.725360; val loss: 1.830247
# (Epoch 9 / 100) train loss: 1.721579; val loss: 1.854314
# (Epoch 10 / 100) train loss: 1.715055; val loss: 1.817114
# (Epoch 11 / 100) train loss: 1.706750; val loss: 1.819143
# (Epoch 12 / 100) train loss: 1.701582; val loss: 1.802707
# (Epoch 13 / 100) train loss: 1.697535; val loss: 1.821675
# (Epoch 14 / 100) train loss: 1.696846; val loss: 1.812922
# (Epoch 15 / 100) train loss: 1.697889; val loss: 1.796631
# (Epoch 16 / 100) train loss: 1.684727; val loss: 1.809878
# (Epoch 17 / 100) train loss: 1.692346; val loss: 1.808479
# (Epoch 18 / 100) train loss: 1.686207; val loss: 1.822329
# (Epoch 19 / 100) train loss: 1.695760; val loss: 1.793798
# (Epoch 20 / 100) train loss: 1.679401; val loss: 1.787233
# (Epoch 21 / 100) train loss: 1.672998; val loss: 1.782830
# (Epoch 22 / 100) train loss: 1.670850; val loss: 1.791516
# (Epoch 23 / 100) train loss: 1.665278; val loss: 1.786520
# (Epoch 24 / 100) train loss: 1.671897; val loss: 1.775515
# (Epoch 25 / 100) train loss: 1.662557; val loss: 1.785908
# (Epoch 26 / 100) train loss: 1.664275; val loss: 1.764693
# (Epoch 27 / 100) train loss: 1.655456; val loss: 1.784483
# (Epoch 28 / 100) train loss: 1.666070; val loss: 1.793065
# (Epoch 29 / 100) train loss: 1.653960; val loss: 1.788737
# (Epoch 30 / 100) train loss: 1.656377; val loss: 1.791669
# (Epoch 31 / 100) train loss: 1.667539; val loss: 1.781176
# (Epoch 32 / 100) train loss: 1.645601; val loss: 1.769774
# (Epoch 33 / 100) train loss: 1.651953; val loss: 1.781694
# (Epoch 34 / 100) train loss: 1.654750; val loss: 1.767613
# (Epoch 35 / 100) train loss: 1.643758; val loss: 1.755548
# (Epoch 36 / 100) train loss: 1.648077; val loss: 1.769085
# (Epoch 37 / 100) train loss: 1.636326; val loss: 1.761545
# (Epoch 38 / 100) train loss: 1.643357; val loss: 1.766214
# (Epoch 39 / 100) train loss: 1.641476; val loss: 1.779514
# (Epoch 40 / 100) train loss: 1.655396; val loss: 1.758852
# (Epoch 41 / 100) train loss: 1.641626; val loss: 1.770419
# (Epoch 42 / 100) train loss: 1.640743; val loss: 1.756418
# (Epoch 43 / 100) train loss: 1.637302; val loss: 1.751377
# (Epoch 44 / 100) train loss: 1.634805; val loss: 1.765407
# (Epoch 45 / 100) train loss: 1.635006; val loss: 1.765306
# (Epoch 46 / 100) train loss: 1.641506; val loss: 1.808944
# (Epoch 47 / 100) train loss: 1.642952; val loss: 1.750283
# (Epoch 48 / 100) train loss: 1.622342; val loss: 1.759920
# (Epoch 49 / 100) train loss: 1.640207; val loss: 1.749742
# (Epoch 50 / 100) train loss: 1.623120; val loss: 1.757936
# (Epoch 51 / 100) train loss: 1.621486; val loss: 1.750719
# (Epoch 52 / 100) train loss: 1.623860; val loss: 1.765824
# (Epoch 53 / 100) train loss: 1.627112; val loss: 1.738500
# (Epoch 54 / 100) train loss: 1.626344; val loss: 1.743960
# (Epoch 55 / 100) train loss: 1.635228; val loss: 1.756988
# (Epoch 56 / 100) train loss: 1.626134; val loss: 1.736425
# (Epoch 57 / 100) train loss: 1.630968; val loss: 1.746765
# (Epoch 58 / 100) train loss: 1.615034; val loss: 1.732630
# (Epoch 59 / 100) train loss: 1.603955; val loss: 1.734216
# (Epoch 60 / 100) train loss: 1.610950; val loss: 1.743933
# (Epoch 61 / 100) train loss: 1.624953; val loss: 1.737207
# (Epoch 62 / 100) train loss: 1.614569; val loss: 1.751748
# (Epoch 63 / 100) train loss: 1.615801; val loss: 1.757040
# (Epoch 64 / 100) train loss: 1.625703; val loss: 1.750587
# (Epoch 65 / 100) train loss: 1.609266; val loss: 1.738634
# (Epoch 66 / 100) train loss: 1.618144; val loss: 1.771643
# (Epoch 67 / 100) train loss: 1.624240; val loss: 1.742454
# (Epoch 68 / 100) train loss: 1.608879; val loss: 1.745718
# (Epoch 69 / 100) train loss: 1.605536; val loss: 1.749544
# (Epoch 70 / 100) train loss: 1.609626; val loss: 1.754608
# (Epoch 71 / 100) train loss: 1.605908; val loss: 1.731713
# (Epoch 72 / 100) train loss: 1.603669; val loss: 1.751019
# (Epoch 73 / 100) train loss: 1.611905; val loss: 1.743355
# (Epoch 74 / 100) train loss: 1.602772; val loss: 1.754852
# (Epoch 75 / 100) train loss: 1.612585; val loss: 1.738769
# (Epoch 76 / 100) train loss: 1.601539; val loss: 1.743329
# (Epoch 77 / 100) train loss: 1.617471; val loss: 1.773471
# (Epoch 78 / 100) train loss: 1.628661; val loss: 1.760237
# (Epoch 79 / 100) train loss: 1.620485; val loss: 1.754324
# (Epoch 80 / 100) train loss: 1.611008; val loss: 1.746480
# (Epoch 81 / 100) train loss: 1.614204; val loss: 1.726209
# (Epoch 82 / 100) train loss: 1.597514; val loss: 1.760777
# (Epoch 83 / 100) train loss: 1.609965; val loss: 1.748286
# (Epoch 84 / 100) train loss: 1.610582; val loss: 1.750017
# (Epoch 85 / 100) train loss: 1.603299; val loss: 1.726792
# (Epoch 86 / 100) train loss: 1.600007; val loss: 1.757461
# (Epoch 87 / 100) train loss: 1.609087; val loss: 1.739907
# (Epoch 88 / 100) train loss: 1.600251; val loss: 1.746291
# (Epoch 89 / 100) train loss: 1.603730; val loss: 1.735262
# (Epoch 90 / 100) train loss: 1.613303; val loss: 1.751691
# (Epoch 91 / 100) train loss: 1.612346; val loss: 1.756857
# (Epoch 92 / 100) train loss: 1.600203; val loss: 1.740547
# (Epoch 93 / 100) train loss: 1.612361; val loss: 1.737838
# (Epoch 94 / 100) train loss: 1.605358; val loss: 1.734699
# (Epoch 95 / 100) train loss: 1.607205; val loss: 1.738886
# (Epoch 96 / 100) train loss: 1.610698; val loss: 1.755899
# (Epoch 97 / 100) train loss: 1.613769; val loss: 1.752119
# (Epoch 98 / 100) train loss: 1.614856; val loss: 1.750827
# (Epoch 99 / 100) train loss: 1.606383; val loss: 1.738206
# (Epoch 100 / 100) train loss: 1.604252; val loss: 1.733210

# %% [markdown]
# Now it's time to edit the ranges above and adjust them to explore regions that performed well!
#
# Also, feel free to experiment around! Also the network architecture, optimizer options and activations functions, etc. are hyperparameters that you can change!
#
# Try to get your accuracy as high as possible! That's all what counts for this submission!
#
# You'll pass if you reach at least **48%** accuracy on our test set - but there will also be a leaderboard of all students of this course. Will you make it to the top?

# %% [markdown]
# ## 3.5 Checking the validation accuracy

# %%
labels, pred, acc = best_model.get_dataset_prediction(dataloaders['train'])
print("Train Accuracy: {}%".format(acc*100))
labels, pred, acc = best_model.get_dataset_prediction(dataloaders['val'])
print("Validation Accuracy: {}%".format(acc*100))
# Out:
# Train Accuracy: 53.723333333333336%
# Validation Accuracy: 47.32572115384615%

# %% [markdown]
# # 4. Test your model
# When you have finished your hyperparameter tuning and are sure you have your final model that performs well on the validation set (**you should at least get 48% accuracy on the validation set!**), it's time to run your  model on the test set.
#
# <div class="alert alert-danger">
#     <h3>Important</h3>
#     <p>As you have learned in the lecture, you must only use the test set one single time! So only run the next cell if you are really sure your model works well enough and that you want to submit. Your test set is different from the test set on our server, so results may vary. Nevertheless, you will have a reasonable close approximation about your performance if you only do a final evaluation on the test set.</p>
#     <p>If you are an external student that can't use our submission webpage: this test performance is your final result and if you surpassed the threshold, you have completed this exercise :). Now, train again to aim for a better number!</p>
# </div>

# %%
# comment this part out to see your model's performance on the test set.
labels, pred, acc = best_model.get_dataset_prediction(dataloaders['test'])
print("Test Accuracy: {}%".format(acc*100))
# Out:
# Test Accuracy: 47.48597756410257%

# %% [markdown]
# <div class="alert alert-warning">
#     <h3>Note:</h3>
#     <p>The "real" test set is actually the dataset we're using for testing your model, which is <b>different</b> from the test-set you're using here.</p>
# </div>

# %% [markdown]
# # 5. Saving your Model

# %%
from exercise_code.tests import save_pickle
save_pickle({"cifar_fcn": best_model}, "cifar_fcn.p")

# %%
from exercise_code.submit import submit_exercise

submit_exercise('exercise06')
# Out:
# relevant folders: ['models', 'exercise_code']
# notebooks files: ['1.cifar10_classification.ipynb']
# Adding folder models
# Adding folder exercise_code
# Adding notebook 1.cifar10_classification.ipynb
# Zipping successful! Zip is stored under: /home/jamesqian/Documents/DeepVision/HW6/exercise06.zip
